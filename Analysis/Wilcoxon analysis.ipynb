# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('sample_data/Samrat.csv')

# %%
df
# Out:
#      VGG16   VGG19  InceptionV3  ...  DenseNet121   NFNet  Modified
# 0   0.8478  0.8542       0.8498  ...       0.8463  0.8976    0.9160
# 1   0.8524  0.8594       0.8553  ...       0.8594  0.9024    0.9060
# 2   0.8589  0.8657       0.8713  ...       0.8689  0.9045    0.9320
# 3   0.8645  0.8756       0.8885  ...       0.8756  0.9087    0.9250
# 4   0.8677  0.8891       0.8897  ...       0.8972  0.9113    0.9300
# 5   0.8693  0.9062       0.8928  ...       0.9062  0.9182    0.9450
# 6   0.8813  0.9124       0.8931  ...       0.9145  0.9217    0.9260
# 7   0.8825  0.9375       0.8937  ...       0.9375  0.9240    0.9177
# 8   0.8836  0.9383       0.8984  ...       0.9388  0.9253    0.9102
# 9   0.8840  0.9352       0.9002  ...       0.9423  0.9266    0.9125
# 10  0.8867  0.9326       0.9067  ...       0.9427  0.9278    0.9260
# 11  0.8892  0.9385       0.9123  ...       0.9435  0.9287    0.9345
# 12  0.8957  0.9423       0.9134  ...       0.9398  0.9312    0.9412
# ...

# %%
from scipy.stats import wilcoxon

# %%
models = ['VGG16','VGG19','InceptionV3','ResNet50','ResNet101','GoogLeNet','MobileNetV2','AlexNet','EfficientNetB7','DenseNet121','NFNet','Modified'] 
models_pair = [(a, b) for idx, a in enumerate(models) for b in models[idx + 1:]]
models_pair
# Out:
# [('VGG16', 'VGG19'),
#  ('VGG16', 'InceptionV3'),
#  ('VGG16', 'ResNet50'),
#  ('VGG16', 'ResNet101'),
#  ('VGG16', 'GoogLeNet'),
#  ('VGG16', 'MobileNetV2'),
#  ('VGG16', 'AlexNet'),
#  ('VGG16', 'EfficientNetB7'),
#  ('VGG16', 'DenseNet121'),
#  ('VGG16', 'NFNet'),
#  ('VGG16', 'Modified'),
#  ('VGG19', 'InceptionV3'),
#  ('VGG19', 'ResNet50'),
#  ('VGG19', 'ResNet101'),
#  ('VGG19', 'GoogLeNet'),
#  ('VGG19', 'MobileNetV2'),
#  ('VGG19', 'AlexNet'),
#  ('VGG19', 'EfficientNetB7'),
#  ('VGG19', 'DenseNet121'),
#  ('VGG19', 'NFNet'),
#  ('VGG19', 'Modified'),
#  ('InceptionV3', 'ResNet50'),
#  ('InceptionV3', 'ResNet101'),
#  ('InceptionV3', 'GoogLeNet'),
#  ('InceptionV3', 'MobileNetV2'),
#  ('InceptionV3', 'AlexNet'),
#  ('InceptionV3', 'EfficientNetB7'),
#  ('InceptionV3', 'DenseNet121'),
#  ('InceptionV3', 'NFNet'),
#  ('InceptionV3', 'Modified'),
#  ('ResNet50', 'ResNet101'),
#  ('ResNet50', 'GoogLeNet'),
#  ('ResNet50', 'MobileNetV2'),
#  ('ResNet50', 'AlexNet'),
# ...

# %%
wilcoxons = {
    'VGG16': ['-'],
    'VGG19': ['-', '-'],
    'InceptionV3': ['-', '-', '-'],
    'ResNet50': ['-', '-', '-', '-'],
    'ResNet101': ['-', '-', '-', '-', '-'],
    'GoogLeNet': ['-', '-', '-', '-', '-', '-'],
    'MobileNetV2': ['-', '-', '-', '-', '-', '-', '-'],
    'AlexNet': ['-', '-', '-', '-', '-', '-', '-','-'],
    'EfficientNetB7': ['-', '-', '-', '-', '-', '-', '-','-','-'],
    'DenseNet121': ['-', '-', '-', '-', '-', '-', '-','-','-','-'],
    'NFNet': ['-', '-', '-', '-', '-', '-', '-','-','-','-','-'],
    'Modified': ['-', '-', '-', '-', '-', '-', '-','-','-','-','-','-'],
}
for models in models_pair:
  f = str(models[0])
  s = str(models[1])
  w, p = wilcoxon(df[f], df[s], correction=True)
  wilcoxons[f].append(p)
  print('Wilcoxon value of {} and {}: {}'.format(f, s, p))
# Out:
# Wilcoxon value of VGG16 and VGG19: 9.569173157059432e-05
# Wilcoxon value of VGG16 and InceptionV3: 9.569173157059432e-05
# Wilcoxon value of VGG16 and ResNet50: 9.569173157059432e-05
# Wilcoxon value of VGG16 and ResNet101: 0.00012992610033373927
# Wilcoxon value of VGG16 and GoogLeNet: 0.04999986301138254
# Wilcoxon value of VGG16 and MobileNetV2: 0.00031617314479660276
# Wilcoxon value of VGG16 and AlexNet: 0.00023126651526045132
# Wilcoxon value of VGG16 and EfficientNetB7: 0.03825204444825584
# Wilcoxon value of VGG16 and DenseNet121: 0.00011126928015754344
# Wilcoxon value of VGG16 and NFNet: 9.569173157059432e-05
# Wilcoxon value of VGG16 and Modified: 9.569173157059432e-05
# Wilcoxon value of VGG19 and InceptionV3: 0.000833948987816244
# Wilcoxon value of VGG19 and ResNet50: 9.569173157059432e-05
# Wilcoxon value of VGG19 and ResNet101: 0.18495477148896955
# Wilcoxon value of VGG19 and GoogLeNet: 9.569173157059432e-05
# ...

# %%
wilcoxons
# Out:
# {'AlexNet': ['-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   9.569173157059432e-05,
#   9.569173157059432e-05,
#   9.569173157059432e-05,
#   9.569173157059432e-05],
#  'DenseNet121': ['-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   0.40934420457023923,
#   0.006797230872264168],
#  'EfficientNetB7': ['-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   9.569173157059432e-05,
#   9.569173157059432e-05,
#   9.569173157059432e-05],
#  'GoogLeNet': ['-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   0.003382922253745841,
#   0.5628210544183155,
#   0.008489555376820024,
#   0.00014302007339316058,
#   0.00014302007339316058,
#   9.569173157059432e-05],
#  'InceptionV3': ['-',
#   '-',
#   '-',
#   9.555744839077428e-05,
#   0.0004178397418527953,
#   0.00014302007339316058,
#   0.30458604753525,
#   9.569173157059432e-05,
#   9.569173157059432e-05,
#   0.011539554953844918,
# ...

# %%
pdf = pd.DataFrame(wilcoxons)

# %%
pdf
# Out:
#           VGG16        VGG19  InceptionV3  ... DenseNet121       NFNet Modified
# 0             -            -            -  ...           -           -        -
# 1   9.56917e-05            -            -  ...           -           -        -
# 2   9.56917e-05  0.000833949            -  ...           -           -        -
# 3   9.56917e-05  9.56917e-05  9.55574e-05  ...           -           -        -
# 4   0.000129926     0.184955   0.00041784  ...           -           -        -
# 5     0.0499999  9.56917e-05   0.00014302  ...           -           -        -
# 6   0.000316173     0.444081     0.304586  ...           -           -        -
# 7   0.000231267  9.56917e-05  9.56917e-05  ...           -           -        -
# 8      0.038252  9.56917e-05  9.56917e-05  ...           -           -        -
# 9   0.000111269     0.187312    0.0115396  ...           -           -        -
# 10  9.56917e-05     0.866586  0.000368836  ...    0.409344           -        -
# ...

# %%
pdf.to_csv('Wilcoxon_ModelComparison.csv', index=False)

# %%
from google.colab import files
files.download('Wilcoxon_ModelComparison.csv')

# %%
pdf
# Out:
#           VGG16        VGG19  InceptionV3  ... DenseNet121     NFNet AAA
# 0             -            -            -  ...           -         -   -
# 1   0.000202835            -            -  ...           -         -   -
# 2   0.000192362   0.00185585            -  ...           -         -   -
# 3   0.000131388  0.000117573  0.000135183  ...           -         -   -
# 4    0.00029922     0.354336   0.00130351  ...           -         -   -
# 5     0.0190165   0.00014125  0.000211511  ...           -         -   -
# 6   0.000128696  0.000117765  0.000135824  ...           -         -   -
# 7   0.000467819   0.00014125  0.000137327  ...           -         -   -
# 8      0.118479  0.000129314  0.000285848  ...           -         -   -
# 9   0.000203905     0.171634    0.0104843  ...           -         -   -
# 10  0.000125844     0.389883  0.000630401  ...   0.0832114         -   -
# 11     0.111315     0.161336      0.39446  ...    0.358595  0.282883   -
#
# ...

# %%
pdf.to_csv('Wilcoxon_Boruta.csv', index=False)

# %%
from google.colab import files
files.download('Wilcoxon_Boruta.csv')

# %%
#data = pd.read_csv('sample_data/Accuracy_Boruta.csv')

data = data.transpose()
data.columns = data.iloc[0]
data = data.drop(data.index[0])
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-30dcf35c0ad0> in <module>()
#       1 #data = pd.read_csv('sample_data/Accuracy_Boruta.csv')
#       2
# ----> 3 data = data.transpose()
#       4 data.columns = data.iloc[0]
#       5 data = data.drop(data.index[0])
#
# NameError: name 'data' is not defined

# %%
plt.rcParams["figure.figsize"] = [18,10]
barWidth = 0.08
# fig = plt.subplots(figsize =(18, 10))
br1 = np.arange(len(data['ANN']))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]
br5 = [x + barWidth for x in br4]
br6 = [x + barWidth for x in br5]
br7 = [x + barWidth for x in br6]
# Make the plot
plt.bar(br1, data['ANN'], color ='gray', width = barWidth,
        edgecolor ='grey', label ='ANN')
plt.bar(br2, data['LSTM'], color ='gainsboro', width = barWidth,
        edgecolor ='grey', label ='LSTM')
plt.bar(br3, data['BiLSTM'], color ='moccasin', width = barWidth,
        edgecolor ='grey', label ='Bidirectional LSTM')
plt.bar(br4, data['GRU'], color ='#80bfff', width = barWidth,
        edgecolor ='grey', label ='GRU')
plt.bar(br5, data['BiGRU'], color ='#b3ffb3', width = barWidth,
        edgecolor ='grey', label ='Bidirectional GRU')
plt.bar(br6, data['SimpleRNN'], color ='#ffe6b3', width = barWidth,
        edgecolor ='grey', label ='Simple RNN')
plt.bar(br7, data[' MLP'], color ='#ffff99', width = barWidth,
        edgecolor ='grey', label ='Multi-Layer Perceptron')

# Adding Xticks
plt.xlabel('Models', fontsize = 20)
plt.ylabel('Accuracy', fontsize = 20)
plt.xticks([r + barWidth for r in range(len(data['ANN']))],
        ['Accuracy', 'Precision', 'Recall', 'F1 Score'],fontsize = 15)
plt.yticks(fontsize = 15)
plt.title('Boruta',fontweight ='bold', fontsize = 20)
 
plt.legend(fontsize = 16)
plt.savefig('Accuracy Boruta.png')
plt.show()
