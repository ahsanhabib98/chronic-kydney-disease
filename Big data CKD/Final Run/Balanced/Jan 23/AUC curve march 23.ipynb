# %%
import pandas as pd
import numpy as np
import pandas
import numpy
import math
import warnings
import time
import matplotlib.pyplot as plt

from collections import Counter
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV
from sklearn.utils import shuffle
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor
from sklearn.metrics import roc_curve, auc, accuracy_score,roc_auc_score,mean_absolute_error,r2_score

from scipy import stats
import pickle

warnings.filterwarnings('ignore')

# %%
import h5py as h5
import scipy.io as sio
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from os import listdir
from tensorflow.keras.preprocessing import sequence
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten, Embedding, Dropout, Activation, Reshape
#from tensorflow.keras.layers import Dense, Conv1D, MaxPooling1D, GlobalAveragePooling1D, TimeDistributed
from tensorflow.keras.layers import LSTM
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
#dataset = pd.read_csv('sample_data/data_CKD_MI.csv')

# %%
dataset = pd.read_csv('sample_data/data_CKD_bigdata_refined.csv')
print(dataset.shape)
df = dataset.dropna()
print(df.shape)
df.describe()
# Out:
# (1000000, 29)
# (1000000, 29)
#                   sex             age            sido         height  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.00000
# mean         1.469590       52.635205       33.694584      162.22823
# std          0.499075       14.205915       12.672969        9.28462
# min          1.000000       25.000000       11.000000      130.00000
# 25%          1.000000       40.000000       27.000000      155.00000
# 50%          1.000000       50.000000       41.000000      160.00000
# 75%          2.000000       65.000000       43.000000      170.00000
# max          2.000000       90.000000       50.000000      190.00000
#
#                weight           waist     vision_left    vision_right  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean        63.268710       81.230185        0.980466        0.978019
# std         12.520732       11.837045        0.608758        0.607068
# min         25.000000        8.000000        0.100000        0.100000
# 25%         55.000000       74.100000        0.700000        0.700000
# 50%         60.000000       81.000000        1.000000        1.000000
# 75%         70.000000       87.800000        1.200000        1.200000
# max        140.000000      999.000000        9.900000        9.900000
#
#           listen_left    listen_right  ...      CREATININE        SGOT_AST  \
# count  1000000.000000  1000000.000000  ...  1000000.000000  1000000.000000
# mean         1.031707        1.030689  ...        0.862169       25.994604
# std          0.175200        0.172455  ...        0.498426       23.587013
# min          0.958226        0.956816  ...        0.100000       -1.716939
# 25%          1.000000        1.000000  ...        0.700000       19.000000
# 50%          1.000000        1.000000  ...        0.800000       23.000000
# 75%          1.000000        1.000000  ...        1.000000       28.000000
# max          2.000000        2.000000  ...       98.000000     9999.000000
#
#              SGPT_ALT       GAMMA_GTP  SMK_STAT_TYPE_RSPS_CD    DRINK_OR_NOT  \
# count  1000000.000000  1000000.000000         1000000.000000  1000000.000000
# mean        25.750859       37.184051               1.607675        0.499248
# std         26.335240       50.623388               0.818417        0.499898
# min          1.000000        1.000000               0.813515       -0.113279
# 25%         15.000000       16.000000               1.000000        0.000000
# 50%         20.000000       23.000000               1.000000        0.000000
# 75%         29.000000       39.000000               2.000000        1.000000
# max       7210.000000      999.000000               3.000000        1.432356
#
#           MOUTH_CHECK             BMI             GFR           stage
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         0.400523       23.914610       92.440625        1.566124
# std          0.490005        3.516791       31.420343        0.580398
# min          0.000000       12.486993        0.317448        1.000000
# 25%          0.000000       21.484375       77.123612        1.000000
# 50%          0.000000       23.875115       89.324053        2.000000
# 75%          1.000000       25.951557      103.940178        2.000000
# max          1.000000       45.714286     1353.095368        5.000000
#
# [8 rows x 29 columns]

# %%
# dataset = dataset.head()
# dataset

# %%
dataset.shape
# Out:
# (1000000, 29)

# %%
dataset.isnull().sum()
# Out:
# sex                      0
# age                      0
# sido                     0
# height                   0
# weight                   0
# waist                    0
# vision_left              0
# vision_right             0
# listen_left              0
# listen_right             0
# BP_HIGH                  0
# BP_LWST                  0
# BLDS                     0
# TOT_CHOLE                0
# TRIGLYCERIDE             0
# HDL_CHOLE                0
# LDL_CHOLE                0
# HMG                      0
# OLIG_PROTE_CD            0
# CREATININE               0
# SGOT_AST                 0
# SGPT_ALT                 0
# GAMMA_GTP                0
# SMK_STAT_TYPE_RSPS_CD    0
# DRINK_OR_NOT             0
# MOUTH_CHECK              0
# BMI                      0
# GFR                      0
# stage                    0
# dtype: int64

# %%
# dataset = dataset[dataset[ 'CREATININE ']<=15]

# %%
# dataset = dataset[dataset]

# %%
dataset = dataset.head(50000)
dataset
# Out:
#        sex  age  sido  height  weight  waist  vision_left  vision_right  \
# 0        1   40    43     170      75   90.0          1.0           1.0
# 1        1   35    11     180      80   89.0          0.9           1.2
# 2        1   45    41     165      75   91.0          1.2           1.5
# 3        1   55    48     175      80   91.0          1.5           1.2
# 4        1   55    30     165      60   80.0          1.0           1.2
# ...    ...  ...   ...     ...     ...    ...          ...           ...
# 49995    1   50    41     175      85   95.0          1.2           1.0
# 49996    1   65    41     170      70   79.0          0.7           0.7
# 49997    1   60    41     165      50   74.0          1.0           1.2
# 49998    2   50    31     155      50   75.0          1.0           1.0
# 49999    2   40    11     165      55   76.0          2.0           1.5
#
#        listen_left  listen_right  ...  CREATININE  SGOT_AST  SGPT_ALT  \
# 0              1.0           1.0  ...         1.0      21.0      35.0
# 1              1.0           1.0  ...         0.9      20.0      36.0
# 2              1.0           1.0  ...         0.9      47.0      32.0
# 3              1.0           1.0  ...         1.1      29.0      34.0
# 4              1.0           1.0  ...         0.8      19.0      12.0
# ...            ...           ...  ...         ...       ...       ...
# 49995          1.0           1.0  ...         0.8      24.0      29.0
# 49996          1.0           1.0  ...         1.1      24.0      20.0
# 49997          1.0           1.0  ...         0.9      34.0      40.0
# 49998          1.0           1.0  ...         0.6      20.0      25.0
# 49999          1.0           1.0  ...         0.7      14.0      12.0
#
#        GAMMA_GTP  SMK_STAT_TYPE_RSPS_CD  DRINK_OR_NOT  MOUTH_CHECK        BMI  \
# 0           40.0                    1.0           1.0            1  25.951557
# 1           27.0                    3.0           0.0            1  24.691358
# 2           68.0                    1.0           0.0            0  27.548209
# 3           18.0                    1.0           0.0            1  26.122449
# 4           25.0                    1.0           0.0            1  22.038567
# ...          ...                    ...           ...          ...        ...
# 49995       74.0                    3.0           1.0            1  27.755102
# 49996       24.0                    2.0           0.0            0  24.221453
# 49997       29.0                    3.0           0.0            0  18.365473
# 49998       15.0                    1.0           1.0            0  20.811655
# 49999       13.0                    1.0           1.0            1  20.202020
#
#               GFR  stage
# 0       86.886038      2
# 1      100.644197      1
# 2       95.928640      1
# 3       73.203730      2
# 4      105.714492      1
# ...           ...    ...
# 49995  107.684888      1
# 49996   70.859343      2
# 49997   90.730529      1
# 49998  111.362243      1
# 49999   97.299534      1
#
# [50000 rows x 29 columns]

# %%
dataset.shape
# Out:
# (50000, 29)

# %%
#dataset.iloc[:,:-1]

# %%
#dataset.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split    
from sklearn.preprocessing import MinMaxScaler
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
import keras.layers
from tensorflow.keras.utils import to_categorical
from imblearn.over_sampling import SMOTE
#smote = SMOTE('minority')
# # Data preprocessing
# X = dataset.iloc[:,:-1].values
# y = dataset.iloc[:,-1].values
# print(X.shape)
# print(y.shape)
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 2)
# scaler = MinMaxScaler()
# X_train = scaler.fit_transform(X_train)
# X_test  = scaler.transform(X_test)
# X_train,y_train = smote.fit_resample(X_train,y_train)
# print(X_train.shape,y_train.shape)
# y_train = to_categorical(y_train,dtype="uint8")
# print(y_train.shape)
# y_test = to_categorical(y_test,dtype ="uint8")
# print(y_test.shape)

# print(X_train.shape)
# print(X_test.shape)

# %%
# dataset = dataset.head(961570)
# dataset

# %%
import pandas as pd
import numpy as np
from google.colab import files
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import RandomOverSampler
#from imblearn.under_sampling import RandomUnderSampler
from collections import Counter
from sklearn import metrics
import math
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error

# %%
from sklearn.model_selection import train_test_split    
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
from collections import Counter
#Data preprocessing
X = dataset.iloc[:,:-1].values
y = dataset.iloc[:,-1].values

#X = scaler.fit_transform(X)

# %%
from imblearn.over_sampling import SMOTE

counter = Counter(y)
print('Before',counter)
# oversampling the train dataset using SMOTE
smt = SMOTE()
#X_train, y_train = smt.fit_resample(X_train, y_train)
X_sm, y_sm = smt.fit_resample(X, y)

counter = Counter(y_sm)
print('After',counter)
# Out:
# Before Counter({2: 24239, 1: 23838, 3: 1829, 5: 52, 4: 42})
# After Counter({2: 24239, 1: 24239, 3: 24239, 5: 24239, 4: 24239})

# %%
X_train, X_test, y_train, y_test = train_test_split(X_sm,y_sm, test_size=0.2, random_state = 2)

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test  = scaler.transform(X_test)

# %%
xg_reg = XGBRegressor()
xg_reg.fit(X_train, y_train )
y_train_hat = xg_reg.predict(X_train)
train_r2 = metrics.r2_score(y_true=y_train, y_pred=y_train_hat)
train_rmse = np.sqrt(mean_squared_error(y_train , y_train_hat))
print ('R2: ',train_r2)
print ('RMSE: ', train_rmse)
# Out:
# [23:29:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# R2:  0.99946458313192
# RMSE:  0.032692248459682285

# %%
# from imblearn.combine import SMOTEENN
# counter = Counter(y)
# print('Before',counter)
# # oversampling the train dataset using SMOTE + ENN
# smenn = SMOTEENN()
# X_smenn, y_smenn = smenn.fit_resample(X,y)
# counter = Counter(y_smenn)
# print('After',counter)

# %%
#X_train,X_test,y_train,y_test=train_test_split(X_smenn, y_smenn, train_size=0.8, stratify = y_smenn, random_state=100)

# %%
print(X_train.shape,y_train.shape)
y_train = to_categorical(y_train,dtype="uint8")
print(y_train.shape)
y_test = to_categorical(y_test,dtype ="uint8")
print(y_test.shape)
# Out:
# (96956, 28) (96956,)
# (96956, 6)
# (24239, 6)

# %%
# # ### ANN only
# import time
# start_time = time.time()
# #build the model
# # sequential
# #3 layers firtst 2 nurons and relu function
# #output layer 10 nuron softmax function
# model = Sequential()
# model.add(keras.layers.Dense (128,input_shape=(X_train.shape[1],),activation='relu')) #input layer
# model.add(keras.layers.Dense (64,activation='relu')) #hidden
# model.add(Dropout(.3))
# model.add(keras.layers.Dense (32,activation='relu')) #hidden
# model.add(Dropout(.3))
# model.add(keras.layers.Dense (5,activation='sigmoid')) #output
# model.compile(
#     optimizer = Adam(lr=0.001),
#     loss = 'mse',
#     metrics = ['accuracy']
# )
# history = model.fit(X_train, y_train, epochs=200,batch_size = 2096, validation_data=(X_test, y_test))
# print("--- %s seconds ---" % (time.time() - start_time))

# %%
# y_prob = model.predict(X_test)
# print(y_prob)
# y_classes = y_prob.argmax(axis=-1)
# print(y_classes)

# %%
# from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
# y_classes_1=y_test.argmax(axis=-1)
# mat = confusion_matrix(y_classes_1,y_classes)
# print(mat)
# pl= ConfusionMatrixDisplay(mat,display_labels=range(5))
# # pl.plot()
# # plt.show()

# %%
# from sklearn.metrics import accuracy_score
# print('\nAccuracy: {:.2f}\n'.format(accuracy_score(y_classes_1,y_classes)))

# %%
# from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
# print(precision_score(y_classes_1,y_classes,average='micro'))
# print(recall_score(y_classes_1,y_classes,average="micro"))
# print(f1_score(y_classes_1,y_classes,average="micro"))

# %%
# from sklearn.metrics import classification_report
# print('\nClassification Report\n')
# print(classification_report(y_classes_1,y_classes, target_names=['Stage 1', 'Stage 2', 'Stage 3','Stage 4','Stage 5']))

# %%
# target_names=['Stage 1', 'Stage 2', 'Stage 3','Stage 4','Stage 5']

# %%
# import seaborn as sn
# import pandas as pd 
# fig = plt.subplots(1,1, figsize = (10, 6))
# target_names=['Stage 1', 'Stage 2', 'Stage 3','Stage 4','Stage 5']
# df_cm = pd.DataFrame(mat,target_names,target_names)
# sn.set(font_scale= 2)
# sn.heatmap(df_cm,annot=True,annot_kws={"size":10},cmap='Blues',fmt='g')
# plt.xlabel('Predictions',fontsize=22)
# plt.ylabel('Actual',fontsize=22)
# plt.xticks(fontsize =16)
# plt.yticks(fontsize =16)
# plt.savefig('ANN_ConfusionMatrix.png', dpi=300)
# # from mlxtend.plotting import plot_confusion_matrix
# # fig,ax = plot_confusion_matrix(conf_mat = mat,fontsize=20)
# # plt.xlabel('Predictions',fontsize=18)
# # plt.ylabel('Actual',fontsize=18)

# %%
# from google.colab import files
# files.download('ANN_ConfusionMatrix.png')

# %%
# import matplotlib.pyplot as plt
# fig = plt.gcf()
# plt.style.use('seaborn-white')
# #fig = plt.subplots(1,1, figsize = (12, 8))
# fig.set_size_inches(11,8, forward=True)
# # fig = plt.figure()
# plt.plot(history.history['loss'],'b')
# plt.plot(history.history['val_loss'],'r')
# plt.title('ANN',fontsize = 24)
# plt.xlabel('Epochs',fontsize =22)
# plt.ylabel('Loss',fontsize = 22)
# plt.xticks(fontsize =18)
# plt.yticks(fontsize =18)
# plt.legend(['loss', 'validation loss'], loc='upper right')
# plt.draw()
# plt.savefig('ANN.png', dpi=300)

# %%
# from google.colab import files
# files.download('ANN.png')

# %%
# import matplotlib.pyplot as plt 
# from sklearn.preprocessing import LabelBinarizer
# from sklearn.metrics import roc_curve, auc, roc_auc_score
# #plt.style.use('seaborn-white')

# target= ['Stage 1','Stage 2','Stage 3','Stage 4','Stage 5']

# # set plot figure size
# fig, c_ax = plt.subplots(1,1, figsize = (12, 8))

# # function for scoring roc auc score for multi-class
# def multiclass_roc_auc_score(y_classes_1, y_classes, average="macro"):
#     lb = LabelBinarizer()
#     lb.fit(y_classes_1)
#     y_test = lb.transform(y_classes_1)
#     y_pred = lb.transform(y_classes)

#     for (idx, c_label) in enumerate(target):
#         fpr, tpr, thresholds = roc_curve(y_test[:,idx].astype(int), y_pred[:,idx])
#         c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
#     c_ax.plot(fpr, fpr, 'b-', label = 'Random Guessing')
#     return roc_auc_score(y_test, y_pred, average=average)
# print('ROC AUC score:', multiclass_roc_auc_score(y_classes_1, y_classes))
# c_ax.legend(fontsize=18,)
# #c_ax.legend()
# c_ax.set_xlabel('False Positive Rate',fontsize = 22)
# c_ax.set_ylabel('True Positive Rate',fontsize = 22)
# plt.title('ANN',fontsize = 24)
# plt.xticks(fontsize =18)
# plt.yticks(fontsize =18)
# plt.savefig('ANN_AUC.png', dpi=300)
# plt.show()

# %%
X_train = np.reshape(X_train,(X_train.shape[0],X_train.shape[1],1))
X_test = np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))
print(X_train.shape)
print(X_test.shape)
# Out:
# (96956, 28, 1)
# (24239, 28, 1)

# %%
# # get the model SimpleRNN
from keras.layers import Dense, SimpleRNN
def evaluate_model_SimpleRNN(X_train, X_val, y_train, y_val):
  model = SimpleRNN
  timesteps=125
  dims=4
  model = Sequential()
  model.add(SimpleRNN(units=16, input_shape=(X_train.shape[1],1), activation="relu"))
  model.add(Dense(256, kernel_initializer='he_uniform', activation='relu'))
  model.add(Dense(128, kernel_initializer='he_uniform', activation='relu'))
  model.add(Dense(64, kernel_initializer='he_uniform', activation='relu'))
  model.add(Dense(6, kernel_initializer='he_uniform'))
  model.compile(loss='mse', optimizer=Adam(lr = 0.001), metrics=['accuracy'])
  history = model.fit(X_train, y_train, validation_data = (X_test,y_test), epochs=200, batch_size=5096, verbose=1)
  return history, model

# %%
n_folds = 1
cv_scores, model_history = list(), list()
model = tf.keras.Sequential()
history, model= evaluate_model_SimpleRNN(X_train, X_test, y_train, y_test)
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
# Out:
# Epoch 1/200
# 20/20 [==============================] - 2s 51ms/step - loss: 0.1363 - accuracy: 0.2726 - val_loss: 0.1230 - val_accuracy: 0.3739
# Epoch 2/200
# 20/20 [==============================] - 1s 41ms/step - loss: 0.1165 - accuracy: 0.3846 - val_loss: 0.1072 - val_accuracy: 0.4584
# Epoch 3/200
# 20/20 [==============================] - 1s 41ms/step - loss: 0.0986 - accuracy: 0.5251 - val_loss: 0.0884 - val_accuracy: 0.6063
# Epoch 4/200
# 20/20 [==============================] - 1s 42ms/step - loss: 0.0821 - accuracy: 0.7019 - val_loss: 0.0736 - val_accuracy: 0.7920
# Epoch 5/200
# 20/20 [==============================] - 1s 42ms/step - loss: 0.0683 - accuracy: 0.8391 - val_loss: 0.0614 - val_accuracy: 0.8470
# Epoch 6/200
# 20/20 [==============================] - 1s 42ms/step - loss: 0.0563 - accuracy: 0.8980 - val_loss: 0.0491 - val_accuracy: 0.9241
# Epoch 7/200
# 20/20 [==============================] - 1s 44ms/step - loss: 0.0435 - accuracy: 0.9369 - val_loss: 0.0364 - val_accuracy: 0.9455
# Epoch 8/200
# 20/20 [==============================] - 1s 42ms/step - loss: 0.0315 - accuracy: 0.9523 - val_loss: 0.0301 - val_accuracy: 0.9270
# Epoch 9/200
# 20/20 [==============================] - 1s 41ms/step - loss: 0.0240 - accuracy: 0.9578 - val_loss: 0.0207 - val_accuracy: 0.9585
# Epoch 10/200
# 20/20 [==============================] - 1s 45ms/step - loss: 0.0181 - accuracy: 0.9664 - val_loss: 0.0166 - val_accuracy: 0.9669
# Epoch 11/200
# 20/20 [==============================] - 1s 42ms/step - loss: 0.0151 - accuracy: 0.9723 - val_loss: 0.0142 - val_accuracy: 0.9699
# Epoch 12/200
# 20/20 [==============================] - 1s 44ms/step - loss: 0.
# 20/20 [==============================] - 1s 46ms/step - loss: 0.0043 - accuracy: 0.9904 - val_loss: 0.0043 - val_accuracy: 0.9903
# Epoch 43/200
# 20/20 [==============================] - 1s 43ms/step - loss: 0.0040 - accuracy: 0.9917 - val_loss: 0.0043 - val_accuracy: 0.9918
# Epoch 44/200
# 20/20 [==============================] - 1s 43ms/step - loss: 0.0040 - accuracy: 0.9911 - val_loss: 0.0040 - val_accuracy: 0.9922
# Epoch 45/200
# 20/20 [==============================] - 1s 42ms/step - loss: 0.0039 - accuracy: 0.9919 - val_loss: 0.0043 - val_accuracy: 0.9896
# Epoch 46/200
# 20/20 [==============================] - 1s 42ms/step - loss: 0.0039 - accuracy: 0.9911 - val_loss: 0.0042 - val_accuracy: 0.9885
# Epoch 47/200
# 20/20 [==============================] - 1s 42ms/step - loss: 0.0038 - accuracy: 0.9915 - val_loss: 0.0068 - val_accuracy: 0.9716
# Epoch 48/200
# 20/20 [==============================] - 1s 42ms/step - loss: 0.0044 - accuracy: 0.9887 - val_loss: 0.0039 - val_accuracy: 0.9921
# Epoch 49/200
# 20/20 [==============================] - 1s 46ms/step - loss: 0.0037 - accuracy: 0.9920 - val_loss: 0.0039 - val_accuracy: 0.9935
# Epoch 50/200
# 20/20 [==============================] - 1s 42ms/step - loss: 0.0036 - accuracy: 0.9922 - val_loss: 0.0054 - val_accuracy: 0.9810
# Epoch 51/200
# 20/20 [==============================] - 1s 44ms/step - loss: 0.0040 - accuracy: 0.9905 - val_loss: 0.0059 - val_accuracy: 0.9794
# Epoch 52/200
# 20/20 [==============================] - 1s 43ms/step - loss: 0.0041 - accuracy: 0.9889 - val_loss: 0.0036 - val_accuracy: 0.9918
# Epoch 53/200
# 20/20 [==============================] - 1s 42ms/step - loss: 0.0034 - accuracy: 0.9925 - val_loss: 0.0038 - val_accuracy: 0.9900
# Epoch 54/200
# 20/20 [==============================] - 1s 44ms/step - loss: 0.0033 - accuracy: 0.9926 - val_loss: 0.0058 - val_accuracy: 0.9861
# Epoch 55/200
# 20/20 [==============================] - 1s 42ms/step - loss: 0.0038 - accuracy: 0.9910 - val_loss: 0.0034 - val_accuracy: 0.9925
# Epoch 56/200
# 20/20 [==============================] - 1s 43ms/step - loss: 0.0033 - accuracy: 0.9929 - val_loss: 0.0087 - val_accuracy: 0.9664
# Epoch 57/200
# 20/20 [==============================] - 1s 45ms/step - loss: 0.0051 - accuracy: 0.9876 - val_loss: 0.0048 - val_accuracy: 0.9816
# Epoch 58/200
# 20/20 [==============================] - 1s 43ms/step - loss: 0.0036 - accuracy: 0.9920 - val_loss: 0.0043 - val_accuracy: 0.9880
# Epoch 59/200
# 20/20 [==============================] - 1s 42ms/step - loss: 0.0035 - accuracy: 0.9912 - val_loss: 0.0036 - val_accuracy: 0.9913
# Epoch 60/200
# 20/20 [==============================] - 1s 44ms/step - loss: 0.0032 - accuracy: 0.9919 - val_loss: 0.0037 - val_accuracy: 0.9879
# Epoch 61/200
# 20/20 [==============================] - 1s 41ms/step - loss: 0.0033 - accuracy: 0.9917 - val_loss: 0.0039 - val_accuracy: 0.9851
# Epoch 62/200
# 20/20 [==============================] - 1s 43ms/step - loss: 0.0032 - accuracy: 0.9919 - val_loss: 0.0038 - val_accuracy: 0.9883
# Epoch 63/200
# 20/20 [==============================] - 1s 41ms/step - loss: 0.0032 - accuracy: 0.9920 - val_loss: 0.0032 - val_accuracy: 0.9924
# Epoch 64/200
# 20/20 [==============================] - 1s 41ms/step - loss: 0.0030 - accuracy: 0.9929 - val_loss: 0.0036 - val_accuracy: 0.9891
# Epoch 65/200
# 20/20 [==============================] - 1s 43ms/step - loss: 0.0031 - accuracy: 0.9924 - val_loss: 0.0056 - val_accuracy: 0.9767
# Epoch 66/200
# 20/20 [==============================] - 1s 42ms/step - loss: 0.0036 - accuracy: 0.9890 - val_loss: 0.0051 - val_accuracy: 0.9822
# Epoch 67/200
# 20/20 [==============================] - 1s 42ms/step - loss: 0.0032 - accuracy: 0.9925 - val_loss: 0.0030 - val_accuracy: 0.9929
# Epoch 68/200
# 20/20 [==============================] - 1s 44ms/step - loss: 0.0030 - accuracy: 0.9928 - val_loss: 0.0071 - val_accuracy: 0.9722
# Epoch 69/200
# 20/20 [==============================] - 1s 43ms/step - loss: 0.0040 - accuracy: 0.9883 - val_loss: 0.0035 - val_accuracy: 0.9893
# Epoch 70/200
# 20/20 [==============================] - 1s 42ms/step - loss: 0.0028 - accuracy: 0.9929 - val_loss: 0.0029 - val_accuracy: 0.9925
# Epoch 71/200
# 20/20 [==============================] - 1s 43ms/step - loss: 0.0027 - accuracy: 0.9934 - val_loss: 0.0029 - val_accuracy: 0.9924
# Epoch 72/200
# 20/20 [==============================] - 1s 43ms/step - loss: 0.0029 - accuracy: 0.9926 - val_loss: 0.0041 - val_accuracy: 0.9842
# Epoch 73/200
# 20/20 [==============================] - 1s 42ms/step - loss: 0.
200
# 20/20 [==============================] - 1s 43ms/step - loss: 0.0020 - accuracy: 0.9943 - val_loss: 0.0027 - val_accuracy: 0.9929
# Epoch 199/200
# 20/20 [==============================] - 1s 40ms/step - loss: 0.0023 - accuracy: 0.9941 - val_loss: 0.0019 - val_accuracy: 0.9942
# Epoch 200/200
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0020 - accuracy: 0.9938 - val_loss: 0.0067 - val_accuracy: 0.9784
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
y_prob = model.predict(X_test)
print(y_prob)
y_classes = y_prob.argmax(axis=-1)
print(y_classes)
# Out:
# [[ 3.4414735e-03  9.0287292e-01  1.1563069e-01 -5.8066174e-02
#    3.2639131e-04  1.4251856e-02]
#  [-2.9249135e-03 -3.5539847e-02  4.9885537e-02  9.4333690e-01
#    1.7242428e-02  1.3308575e-02]
#  [ 6.3753184e-03  9.3842232e-01  8.4463775e-02 -4.2554423e-02
#   -2.2001304e-03  1.1894850e-02]
#  ...
#  [ 2.6403125e-03 -2.1813136e-02  2.1365669e-02 -2.2571610e-02
#    1.0071441e+00  5.6444239e-03]
#  [ 3.5705622e-03 -2.4908762e-02  2.2509363e-02 -2.4868296e-02
#    1.0054666e+00  1.0134188e-02]
#  [-2.0519886e-03 -3.6421698e-02  1.0452058e+00 -4.5973822e-02
#    2.8662644e-03  4.3079324e-02]]
# [1 3 1 ... 4 4 2]

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
y_classes_1=y_test.argmax(axis=-1)
mat = confusion_matrix(y_classes_1,y_classes)
print(mat)
pl= ConfusionMatrixDisplay(mat,display_labels=range(5))
# Out:
# [[4566  373    0    0    0]
#  [   0 4779   48    0    0]
#  [   0    0 4814    6    0]
#  [   0    0    0 4782    0]
#  [   2   41   41   13 4774]]

# %%
import pandas as pd
FP = mat.sum(axis=0) - np.diag(mat) 
FN = mat.sum(axis=1) - np.diag(mat)
TP = np.diag(mat)
TN = mat.sum() - (FP + FN + TP)
FP = FP.astype(float)
FN = FN.astype(float)
TP = TP.astype(float)
TN = TN.astype(float)
# Sensitivity, hit rate, recall, or true positive rate
TPR = TP/(TP+FN)
# Specificity or true negative rate
TNR = TN/(TN+FP) 
# Precision or positive predictive value
PPV = TP/(TP+FP)
# Negative predictive value
NPV = TN/(TN+FN)
# Fall out or false positive rate
FPR = FP/(FP+TN)
# False negative rate
FNR = FN/(TP+FN)
# False discovery rate
FDR = FP/(TP+FP)
# Overall accuracy for each class
ACC = (TP+TN)/(TP+FP+FN+TN)
# print(TP)
# print(TN)
# print(FP)
# print(FN)
print(TPR)
print(FPR)
print(FNR)
# Out:
# [0.92447864 0.99005594 0.99875519 1.         0.98008622]
# [0.00010363 0.02132701 0.00458314 0.00097651 0.        ]
# [0.07552136 0.00994406 0.00124481 0.         0.01991378]

# %%
table = pd.DataFrame({'TPR':TPR,'FPR':FPR,'FNR':FNR,'ACCURACY':ACC},index = ['Stage 1', 'Stage 2', 'Stage 3','Stage 4','Stage 5'])
table.round(3)
# Out:
#            TPR    FPR    FNR  ACCURACY
# Stage 1  0.924  0.000  0.076     0.985
# Stage 2  0.990  0.021  0.010     0.981
# Stage 3  0.999  0.005  0.001     0.996
# Stage 4  1.000  0.001  0.000     0.999
# Stage 5  0.980  0.000  0.020     0.996

# %%
from sklearn.metrics import accuracy_score
print('\nAccuracy: {:.2f}\n'.format(accuracy_score(y_classes_1,y_classes)))
# Out:
# Accuracy: 0.98

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
print(precision_score(y_classes_1,y_classes,average='micro'))
print(recall_score(y_classes_1,y_classes,average="micro"))
print(f1_score(y_classes_1,y_classes,average="micro"))
# Out:
# 0.978381946449936
# 0.978381946449936
# 0.978381946449936

# %%
from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_classes_1,y_classes, target_names=['Stage 1', 'Stage 2', 'Stage 3','Stage 4','Stage 5']))
# Out:
# Classification Report
#
#               precision    recall  f1-score   support
#
#      Stage 1       1.00      0.92      0.96      4939
#      Stage 2       0.92      0.99      0.95      4827
#      Stage 3       0.98      1.00      0.99      4820
#      Stage 4       1.00      1.00      1.00      4782
#      Stage 5       1.00      0.98      0.99      4871
#
#     accuracy                           0.98     24239
#    macro avg       0.98      0.98      0.98     24239
# weighted avg       0.98      0.98      0.98     24239

# %%
import seaborn as sn
import pandas as pd 
fig = plt.subplots(1,1, figsize = (10, 6))
target_names=['Stage 1', 'Stage 2', 'Stage 3','Stage 4','Stage 5']
df_cm = pd.DataFrame(mat,target_names,target_names)
sn.set(font_scale= 1.5)
sn.heatmap(df_cm,annot=True,annot_kws={"size":12},cmap='Blues',fmt='g')
plt.xlabel('Predictions',fontsize=18)
plt.ylabel('Actual',fontsize=18)
plt.xticks(fontsize =14)
plt.yticks(fontsize =14)
plt.savefig('RNN-MLP_ConfusionMatrix.png', dpi=100)

# %%
from google.colab import files
files.download('RNN-MLP_ConfusionMatrix.png')

# %%
import matplotlib.pyplot as plt
fig = plt.gcf()
plt.style.use('seaborn-white')
#fig = plt.subplots(1,1, figsize = (12, 8))
fig.set_size_inches(11,8, forward=True)
# fig = plt.figure()
plt.plot(history.history['loss'],'b')
plt.plot(history.history['val_loss'],'r')
plt.title('RNN-MLP',fontsize = 24)
plt.xlabel('Epochs',fontsize =22)
plt.ylabel('Loss',fontsize = 22)
plt.xticks(fontsize =18)
plt.yticks(fontsize =18)
plt.legend(['loss', 'validation loss'], loc='upper right')
plt.draw()
plt.savefig('RNN-MLP.png', dpi=300)

# %%
from google.colab import files
files.download('RNN-MLP.png')

# %%
import matplotlib.pyplot as plt 
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import roc_curve, auc, roc_auc_score
#plt.style.use('seaborn-white')

target= ['Stage 1','Stage 2','Stage 3','Stage 4','Stage 5']

# set plot figure size
fig, c_ax = plt.subplots(1,1, figsize = (12, 8))

# function for scoring roc auc score for multi-class
def multiclass_roc_auc_score(y_classes_1, y_classes, average="macro"):
    lb = LabelBinarizer()
    lb.fit(y_classes_1)
    y_test = lb.transform(y_classes_1)
    y_pred = lb.transform(y_classes)

    for (idx, c_label) in enumerate(target):
        fpr, tpr, thresholds = roc_curve(y_test[:,idx].astype(int), y_pred[:,idx])
        c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
    c_ax.plot(fpr, fpr, 'b-', label = 'Random Guessing')
    return roc_auc_score(y_test, y_pred, average=average)
print('ROC AUC score:', multiclass_roc_auc_score(y_classes_1, y_classes))
c_ax.legend(fontsize=18,)
#c_ax.legend()
c_ax.set_xlabel('False Positive Rate',fontsize = 22)
c_ax.set_ylabel('True Positive Rate',fontsize = 22)
plt.title('RNN-MLP',fontsize = 24)
plt.xticks(fontsize =18)
plt.yticks(fontsize =18)
plt.savefig('RNN-MLP_AUC.png', dpi=300)
plt.show()
# Out:
# ROC AUC score: 0.9866385692387099

# %%
from google.colab import files
files.download('RNN-MLP_AUC.png')

# %%
# SimpleRNN model
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN
from keras.layers import Dense, SimpleRNN
import time
start_time = time.time()
model = Sequential()
model.add(SimpleRNN(units=4, input_shape=(X_train.shape[1],1), activation="relu"))
model.add(Dense(4, activation="relu")) 
model.add(Dense(6))
model.compile(
    optimizer = Adam(lr=0.001),
    loss = 'mse',
    metrics = ['accuracy']
)
history = model.fit(X_train, y_train, epochs=200,batch_size = 5096, validation_data=(X_test, y_test))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Epoch 1/200
# 2/2 [==============================] - 1s 228ms/step - loss: 0.1921 - accuracy: 0.1996 - val_loss: 0.1894 - val_accuracy: 0.2015
# Epoch 2/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1885 - accuracy: 0.1996 - val_loss: 0.1861 - val_accuracy: 0.2015
# Epoch 3/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1852 - accuracy: 0.1996 - val_loss: 0.1830 - val_accuracy: 0.2035
# Epoch 4/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1821 - accuracy: 0.2016 - val_loss: 0.1801 - val_accuracy: 0.2140
# Epoch 5/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1793 - accuracy: 0.2105 - val_loss: 0.1775 - val_accuracy: 0.2258
# Epoch 6/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1766 - accuracy: 0.2199 - val_loss: 0.1750 - val_accuracy: 0.2302
# Epoch 7/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1742 - accuracy: 0.2224 - val_loss: 0.1727 - val_accuracy: 0.2266
# Epoch 8/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1719 - accuracy: 0.2221 - val_loss: 0.1705 - val_accuracy: 0.2286
# Epoch 9/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1697 - accuracy: 0.2208 - val_loss: 0.1685 - val_accuracy: 0.2233
# Epoch 10/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1677 - accuracy: 0.2200 - val_loss: 0.1666 - val_accuracy: 0.2246
# Epoch 11/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1658 - accuracy: 0.2231 - val_loss: 0.1649 - val_accuracy: 0.2310
# Epoch 12/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1641 - accuracy: 0.2337 - val_loss: 0.1632 - val_accuracy: 0.2383
# Epoch 13/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1625 - accuracy: 0.2440 - val_loss: 0.1617 - val_accuracy: 0.2420
# Epoch 14/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1610 - accuracy: 0.2459 - val_loss: 0.1603 - val_accuracy: 0.2436
# Epoch 15/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1596 - accuracy: 0.2492 - val_loss: 0.1590 - val_accuracy: 0.2460
# Epoch 16/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1583 - accuracy: 0.2525 - val_loss: 0.1578 - val_accuracy: 0.2509
# Epoch 17/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1570 - accuracy: 0.2579 - val_loss: 0.1566 - val_accuracy: 0.2537
# Epoch 18/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1559 - accuracy: 0.2628 - val_loss: 0.1555 - val_accuracy: 0.2586
# Epoch 19/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1548 - accuracy: 0.2709 - val_loss: 0.1545 - val_accuracy: 0.2659
# Epoch 20/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1538 - accuracy: 0.2767 - val_loss: 0.1535 - val_accuracy: 0.2687
# Epoch 21/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1528 - accuracy: 0.2801 - val_loss: 0.1526 - val_accuracy: 0.2704
# Epoch 22/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1519 - accuracy: 0.2827 - val_loss: 0.1517 - val_accuracy: 0.2724
# Epoch 23/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1510 - accuracy: 0.2850 - val_loss: 0.1508 - val_accuracy: 0.2752
# Epoch 24/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1501 - accuracy: 0.2860 - val_loss: 0.1500 - val_accuracy: 0.2760
# Epoch 25/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1493 - accuracy: 0.2870 - val_loss: 0.1492 - val_accuracy: 0.2760
# Epoch 26/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1486 - accuracy: 0.2877 - val_loss: 0.1485 - val_accuracy: 0.2769
# Epoch 27/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1478 - accuracy: 0.2883 - val_loss: 0.1477 - val_accuracy: 0.2769
# Epoch 28/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1471 - accuracy: 0.2868 - val_loss: 0.1470 - val_accuracy: 0.2728
# Epoch 29/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1464 - accuracy: 0.2851 - val_loss: 0.1463 - val_accuracy: 0.2687
# Epoch 30/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1458 - accuracy: 0.2790 - val_loss: 0.1457 - val_accuracy: 0.2550
# Epoch 31/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1451 - accuracy: 0.2644 - val_loss: 0.1451 - val_accuracy: 0.2100
# Epoch 32/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1446 - accuracy: 0.2045 - val_loss: 0.1446 - val_accuracy: 0.2015
# Epoch 33/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1440 - accuracy: 0.1996 - val_loss: 0.1440 - val_accuracy: 0.2015
# Epoch 34/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1435 - accuracy: 0.1996 - val_loss: 0.1435 - val_accuracy: 0.2015
# Epoch 35/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1430 - accuracy: 0.1996 - val_loss: 0.1430 - val_accuracy: 0.2015
# Epoch 36/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1425 - accuracy: 0.2140 - val_loss: 0.1425 - val_accuracy: 0.2339
# Epoch 37/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1420 - accuracy: 0.2377 - val_loss: 0.1420 - val_accuracy: 0.2282
# Epoch 38/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1416 - accuracy: 0.2317 - val_loss: 0.1416 - val_accuracy: 0.2221
# Epoch 39/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1412 - accuracy: 0.2251 - val_loss: 0.1412 - val_accuracy: 0.2189
# Epoch 40/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1407 - accuracy: 0.2208 - val_loss: 0.1408 - val_accuracy: 0.2201
# Epoch 41/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1403 - accuracy: 0.2223 - val_loss: 0.1404 - val_accuracy: 0.2209
# Epoch 42/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1400 - accuracy: 0.2255 - val_loss: 0.1399 - val_accuracy: 0.2233
# Epoch 43/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1396 - accuracy: 0.2279 - val_loss: 0.1396 - val_accuracy: 0.2274
# Epoch 44/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1392 - accuracy: 0.2328 - val_loss: 0.1392 - val_accuracy: 0.2323
# Epoch 45/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1388 - accuracy: 0.2379 - val_loss: 0.1388 - val_accuracy: 0.2371
# Epoch 46/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1385 - accuracy: 0.2427 - val_loss: 0.1384 - val_accuracy: 0.2436
# Epoch 47/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1381 - accuracy: 0.2458 - val_loss: 0.1381 - val_accuracy: 0.2481
# Epoch 48/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1378 - accuracy: 0.2503 - val_loss: 0.1378 - val_accuracy: 0.2509
# Epoch 49/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1375 - accuracy: 0.2532 - val_loss: 0.1374 - val_accuracy: 0.2537
# Epoch 50/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1371 - accuracy: 0.2555 - val_loss: 0.1371 - val_accuracy: 0.2558
# Epoch 51/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1368 - accuracy: 0.2575 - val_loss: 0.1368 - val_accuracy: 0.2578
# Epoch 52/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1365 - accuracy: 0.2603 - val_loss: 0.1365 - val_accuracy: 0.2606
# Epoch 53/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1362 - accuracy: 0.2632 - val_loss: 0.1361 - val_accuracy: 0.2643
# Epoch 54/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1359 - accuracy: 0.2652 - val_loss: 0.1358 - val_accuracy: 0.2671
# Epoch 55/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1356 - accuracy: 0.2666 - val_loss: 0.1355 - val_accuracy: 0.2704
# Epoch 56/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.
200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1037 - accuracy: 0.4543 - val_loss: 0.1041 - val_accuracy: 0.4349
# Epoch 182/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1036 - accuracy: 0.4558 - val_loss: 0.1040 - val_accuracy: 0.4362
# Epoch 183/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1034 - accuracy: 0.4568 - val_loss: 0.1039 - val_accuracy: 0.4366
# Epoch 184/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1033 - accuracy: 0.4578 - val_loss: 0.1037 - val_accuracy: 0.4390
# Epoch 185/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1031 - accuracy: 0.4588 - val_loss: 0.1036 - val_accuracy: 0.4414
# Epoch 186/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1030 - accuracy: 0.4595 - val_loss: 0.1034 - val_accuracy: 0.4430
# Epoch 187/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1029 - accuracy: 0.4617 - val_loss: 0.1033 - val_accuracy: 0.4455
# Epoch 188/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1027 - accuracy: 0.4631 - val_loss: 0.1032 - val_accuracy: 0.4475
# Epoch 189/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1026 - accuracy: 0.4647 - val_loss: 0.1030 - val_accuracy: 0.4491
# Epoch 190/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1025 - accuracy: 0.4654 - val_loss: 0.1029 - val_accuracy: 0.4503
# Epoch 191/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1023 - accuracy: 0.4677 - val_loss: 0.1028 - val_accuracy: 0.4524
# Epoch 192/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1022 - accuracy: 0.4688 - val_loss: 0.1027 - val_accuracy: 0.4544
# Epoch 193/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1021 - accuracy: 0.4706 - val_loss: 0.1025 - val_accuracy: 0.4560
# Epoch 194/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1020 - accuracy: 0.4710 - val_loss: 0.1024 - val_accuracy: 0.4589
# Epoch 195/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1019 - accuracy: 0.4717 - val_loss: 0.1023 - val_accuracy: 0.4593
# Epoch 196/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1017 - accuracy: 0.4726 - val_loss: 0.1022 - val_accuracy: 0.4593
# Epoch 197/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1016 - accuracy: 0.4748 - val_loss: 0.1021 - val_accuracy: 0.4605
# Epoch 198/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1015 - accuracy: 0.4760 - val_loss: 0.1019 - val_accuracy: 0.4605
# Epoch 199/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1014 - accuracy: 0.4772 - val_loss: 0.1018 - val_accuracy: 0.4621
# Epoch 200/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1013 - accuracy: 0.4784 - val_loss: 0.1017 - val_accuracy: 0.4641
# --- 12.331591606140137 seconds ---

# %%
y_prob = model.predict(X_test)
print(y_prob)
y_classes = y_prob.argmax(axis=-1)
print(y_classes)
# Out:
# [[-4.55257483e-03  4.01128709e-01  3.95667911e-01  1.33642480e-01
#   -5.88362366e-02  7.59218261e-02]
#  [ 1.33107472e-02  3.15804705e-02  5.69041893e-02  1.15733668e-01
#    4.42065924e-01  3.80587041e-01]
#  [ 1.19392294e-02  4.22324017e-02  7.46715441e-02  1.17620714e-01
#    4.34644192e-01  3.79536271e-01]
#  ...
#  [-6.29630312e-03  3.46648574e-01  3.16204041e-01  1.76803157e-01
#    3.66732478e-04  7.67319277e-02]
#  [-1.60081312e-03  4.45104629e-01  4.14853394e-01  1.53640926e-01
#   -1.35921896e-01  8.61304253e-03]
#  [ 1.79501846e-02  3.49617243e-01  2.80671269e-01  2.02273369e-01
#   -4.55985814e-02  1.06315240e-02]]
# [1 4 4 ... 1 1 1]

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
y_classes_1=y_test.argmax(axis=-1)
mat = confusion_matrix(y_classes_1,y_classes)
print(mat)
pl= ConfusionMatrixDisplay(mat,display_labels=range(5))
# Out:
# [[483  18   0   0   0]
#  [467  29   1   0   0]
#  [246  21 183  46  17]
#  [  0   0   0 450   0]
#  [  0   0   0 506   0]]

# %%
import pandas as pd
FP = mat.sum(axis=0) - np.diag(mat) 
FN = mat.sum(axis=1) - np.diag(mat)
TP = np.diag(mat)
TN = mat.sum() - (FP + FN + TP)
FP = FP.astype(float)
FN = FN.astype(float)
TP = TP.astype(float)
TN = TN.astype(float)
# Sensitivity, hit rate, recall, or true positive rate
TPR = TP/(TP+FN)
# Specificity or true negative rate
TNR = TN/(TN+FP) 
# Precision or positive predictive value
PPV = TP/(TP+FP)
# Negative predictive value
NPV = TN/(TN+FN)
# Fall out or false positive rate
FPR = FP/(FP+TN)
# False negative rate
FNR = FN/(TP+FN)
# False discovery rate
FDR = FP/(TP+FP)
# Overall accuracy for each class
ACC = (TP+TN)/(TP+FP+FN+TN)
# print(TP)
# print(TN)
# print(FP)
# print(FN)
print(TPR)
print(FPR)
print(ACC)
# Out:
# [0.96407186 0.0583501  0.35672515 1.         0.        ]
# [0.36266531 0.01979695 0.00051177 0.27367377 0.00866905]
# [0.70368869 0.79448723 0.86582894 0.77624645 0.78800162]

# %%
table = pd.DataFrame({'TPR':TPR,'FPR':FPR,'FNR':FNR,'ACCURACY':ACC},index = ['Stage 1', 'Stage 2', 'Stage 3','Stage 4','Stage 5'])
table.round(3)
# Out:
#            TPR    FPR    FNR  ACCURACY
# Stage 1  0.964  0.363  0.036     0.704
# Stage 2  0.058  0.020  0.942     0.794
# Stage 3  0.357  0.001  0.643     0.866
# Stage 4  1.000  0.274  0.000     0.776
# Stage 5  0.000  0.009  1.000     0.788

# %%
from sklearn.metrics import accuracy_score
print('\nAccuracy: {:.2f}\n'.format(accuracy_score(y_classes_1,y_classes)))
# Out:
# Accuracy: 0.46

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
print(precision_score(y_classes_1,y_classes,average='micro'))
print(recall_score(y_classes_1,y_classes,average="micro"))
print(f1_score(y_classes_1,y_classes,average="micro"))
# Out:
# 0.4641264693960276
# 0.4641264693960276
# 0.4641264693960276

# %%
from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_classes_1,y_classes, target_names=['Stage 1', 'Stage 2', 'Stage 3','Stage 4','Stage 5']))
# Out:
# Classification Report
#
#               precision    recall  f1-score   support
#
#      Stage 1       0.40      0.96      0.57       501
#      Stage 2       0.43      0.06      0.10       497
#      Stage 3       0.99      0.36      0.53       513
#      Stage 4       0.45      1.00      0.62       450
#      Stage 5       0.00      0.00      0.00       506
#
#     accuracy                           0.46      2467
#    macro avg       0.45      0.48      0.36      2467
# weighted avg       0.46      0.46      0.36      2467

# %%
import seaborn as sn
import pandas as pd 
fig = plt.subplots(1,1, figsize = (10, 6))
target_names=['Stage 1', 'Stage 2', 'Stage 3','Stage 4','Stage 5']
df_cm = pd.DataFrame(mat,target_names,target_names)
sn.set(font_scale= 1.5)
sn.heatmap(df_cm,annot=True,annot_kws={"size":12},cmap='Blues',fmt='g')
plt.xlabel('Predictions',fontsize=18)
plt.ylabel('Actual',fontsize=18)
plt.xticks(fontsize =14)
plt.yticks(fontsize =14)
plt.savefig('RNN_ConfusionMatrix.png', dpi=100)

# %%
from google.colab import files
files.download('RNN_ConfusionMatrix.png')

# %%
import matplotlib.pyplot as plt
fig = plt.gcf()
plt.style.use('seaborn-white')
#fig = plt.subplots(1,1, figsize = (12, 8))
fig.set_size_inches(11,8, forward=True)
# fig = plt.figure()
plt.plot(history.history['loss'],'b')
plt.plot(history.history['val_loss'],'r')
plt.title('RNN',fontsize = 24)
plt.xlabel('Epochs',fontsize =22)
plt.ylabel('Loss',fontsize = 22)
plt.xticks(fontsize =18)
plt.yticks(fontsize =18)
plt.legend(['loss', 'validation loss'], loc='upper right')
plt.draw()
plt.savefig('RNN.png', dpi=300)

# %%
from google.colab import files
files.download('RNN.png')

# %%
import matplotlib.pyplot as plt 
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import roc_curve, auc, roc_auc_score
#plt.style.use('seaborn-white')

target= ['Stage 1','Stage 2','Stage 3','Stage 4','Stage 5']

# set plot figure size
fig, c_ax = plt.subplots(1,1, figsize = (12, 8))

# function for scoring roc auc score for multi-class
def multiclass_roc_auc_score(y_classes_1, y_classes, average="macro"):
    lb = LabelBinarizer()
    lb.fit(y_classes_1)
    y_test = lb.transform(y_classes_1)
    y_pred = lb.transform(y_classes)

    for (idx, c_label) in enumerate(target):
        fpr, tpr, thresholds = roc_curve(y_test[:,idx].astype(int), y_pred[:,idx])
        c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
    c_ax.plot(fpr, fpr, 'b-', label = 'Random Guessing')
    return roc_auc_score(y_test, y_pred, average=average)
print('ROC AUC score:', multiclass_roc_auc_score(y_classes_1, y_classes))
c_ax.legend(fontsize=18,)
#c_ax.legend()
c_ax.set_xlabel('False Positive Rate',fontsize = 22)
c_ax.set_ylabel('True Positive Rate',fontsize = 22)
plt.title('RNN',fontsize = 24)
plt.xticks(fontsize =18)
plt.yticks(fontsize =18)
plt.savefig('RNN_AUC.png', dpi=300)
plt.show()
# Out:
# ROC AUC score: 0.6713830248438784

# %%
from google.colab import files
files.download('RNN_AUC.png')

# %%
 #MLP only
import time
start_time = time.time()
model = keras.models.Sequential()
model.add(keras.layers.BatchNormalization(input_shape=tuple([X_train.shape[1]])))
model.add(keras.layers.Dense(12, activation='relu'))
model.add(keras.layers.Dropout(rate=0.2))
model.add(keras.layers.BatchNormalization())
model.add(keras.layers.Dense(4, activation='relu'))
# model.add(keras.layers.Dense(4, activation='relu'))
# model.add(keras.layers.Dropout(rate=0.2))
model.add(keras.layers.Dense(6, activation='relu'))

model.compile(
    optimizer = Adam(lr=0.001),
    loss = 'mse',
    metrics = ['accuracy']
)
model.fit(X_train, y_train, epochs=200,batch_size = 2048, validation_data=(X_test, y_test))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Epoch 1/200
# 5/5 [==============================] - 1s 44ms/step - loss: 0.5405 - accuracy: 0.1339 - val_loss: 0.1763 - val_accuracy: 0.2355
# Epoch 2/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.4871 - accuracy: 0.1351 - val_loss: 0.1711 - val_accuracy: 0.2298
# Epoch 3/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.4401 - accuracy: 0.1328 - val_loss: 0.1667 - val_accuracy: 0.2262
# Epoch 4/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3937 - accuracy: 0.1441 - val_loss: 0.1632 - val_accuracy: 0.2270
# Epoch 5/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3624 - accuracy: 0.1411 - val_loss: 0.1605 - val_accuracy: 0.2250
# Epoch 6/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3296 - accuracy: 0.1450 - val_loss: 0.1583 - val_accuracy: 0.2221
# Epoch 7/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3075 - accuracy: 0.1503 - val_loss: 0.1566 - val_accuracy: 0.2221
# Epoch 8/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.2853 - accuracy: 0.1541 - val_loss: 0.1552 - val_accuracy: 0.2221
# Epoch 9/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.2646 - accuracy: 0.1591 - val_loss: 0.1540 - val_accuracy: 0.2217
# Epoch 10/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2494 - accuracy: 0.1701 - val_loss: 0.1529 - val_accuracy: 0.2238
# Epoch 11/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2431 - accuracy: 0.1829 - val_loss: 0.1521 - val_accuracy: 0.2290
# Epoch 12/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2293 - accuracy: 0.1786 - val_loss: 0.1515 - val_accuracy: 0.2282
# Epoch 13/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2205 - accuracy: 0.1883 - val_loss: 0.1510 - val_accuracy: 0.2335
# Epoch 14/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.2114 - accuracy: 0.1891 - val_loss: 0.1506 - val_accuracy: 0.2331
# Epoch 15/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.2050 - accuracy: 0.2009 - val_loss: 0.1504 - val_accuracy: 0.2392
# Epoch 16/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.2001 - accuracy: 0.2086 - val_loss: 0.1502 - val_accuracy: 0.2428
# Epoch 17/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1957 - accuracy: 0.2121 - val_loss: 0.1501 - val_accuracy: 0.2497
# Epoch 18/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1875 - accuracy: 0.2146 - val_loss: 0.1501 - val_accuracy: 0.2533
# Epoch 19/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1856 - accuracy: 0.2343 - val_loss: 0.1501 - val_accuracy: 0.2562
# Epoch 20/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1818 - accuracy: 0.2285 - val_loss: 0.1501 - val_accuracy: 0.2562
# Epoch 21/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1805 - accuracy: 0.2373 - val_loss: 0.1502 - val_accuracy: 0.2550
# Epoch 22/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1773 - accuracy: 0.2364 - val_loss: 0.1503 - val_accuracy: 0.2509
# Epoch 23/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1745 - accuracy: 0.2418 - val_loss: 0.1505 - val_accuracy: 0.2501
# Epoch 24/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1706 - accuracy: 0.2416 - val_loss: 0.1507 - val_accuracy: 0.2481
# Epoch 25/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1700 - accuracy: 0.2454 - val_loss: 0.1508 - val_accuracy: 0.2452
# Epoch 26/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1645 - accuracy: 0.2556 - val_loss: 0.1509 - val_accuracy: 0.2436
# Epoch 27/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1616 - accuracy: 0.2535 - val_loss: 0.1508 - val_accuracy: 0.2367
# Epoch 28/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1613 - accuracy: 0.2599 - val_loss: 0.1507 - val_accuracy: 0.2379
# Epoch 29/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1618 - accuracy: 0.2532 - val_loss: 0.1505 - val_accuracy: 0.2469
# Epoch 30/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1577 - accuracy: 0.2588 - val_loss: 0.1502 - val_accuracy: 0.2493
# Epoch 31/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1577 - accuracy: 0.2632 - val_loss: 0.1499 - val_accuracy: 0.2485
# Epoch 32/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1540 - accuracy: 0.2694 - val_loss: 0.1495 - val_accuracy: 0.2489
# Epoch 33/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1536 - accuracy: 0.2680 - val_loss: 0.1490 - val_accuracy: 0.2525
# Epoch 34/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1534 - accuracy: 0.2696 - val_loss: 0.1484 - val_accuracy: 0.2525
# Epoch 35/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1508 - accuracy: 0.2709 - val_loss: 0.1478 - val_accuracy: 0.2546
# Epoch 36/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1497 - accuracy: 0.2780 - val_loss: 0.1471 - val_accuracy: 0.2562
# Epoch 37/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1482 - accuracy: 0.2816 - val_loss: 0.1464 - val_accuracy: 0.2578
# Epoch 38/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.
200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1197 - accuracy: 0.4512 - val_loss: 0.1182 - val_accuracy: 0.4994
# Epoch 70/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1191 - accuracy: 0.4585 - val_loss: 0.1171 - val_accuracy: 0.5034
# Epoch 71/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1184 - accuracy: 0.4576 - val_loss: 0.1160 - val_accuracy: 0.5059
# Epoch 72/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1172 - accuracy: 0.4704 - val_loss: 0.1150 - val_accuracy: 0.5099
# Epoch 73/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1171 - accuracy: 0.4743 - val_loss: 0.1140 - val_accuracy: 0.5124
# Epoch 74/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1167 - accuracy: 0.4732 - val_loss: 0.1130 - val_accuracy: 0.5172
# Epoch 75/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1159 - accuracy: 0.4778 - val_loss: 0.1120 - val_accuracy: 0.5209
# Epoch 76/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1155 - accuracy: 0.4827 - val_loss: 0.1110 - val_accuracy: 0.5237
# Epoch 77/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1149 - accuracy: 0.4856 - val_loss: 0.1101 - val_accuracy: 0.5270
# Epoch 78/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1142 - accuracy: 0.4914 - val_loss: 0.1091 - val_accuracy: 0.5359
# Epoch 79/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1130 - accuracy: 0.4966 - val_loss: 0.1080 - val_accuracy: 0.5420
# Epoch 80/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1131 - accuracy: 0.4971 - val_loss: 0.1070 - val_accuracy: 0.5480
# Epoch 81/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1121 - accuracy: 0.5061 - val_loss: 0.1060 - val_accuracy: 0.5574
# Epoch 82/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1113 - accuracy: 0.5097 - val_loss: 0.1050 - val_accuracy: 0.5610
# Epoch 83/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1103 - accuracy: 0.5131 - val_loss: 0.1039 - val_accuracy: 0.5630
# Epoch 84/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1098 - accuracy: 0.5164 - val_loss: 0.1029 - val_accuracy: 0.5667
# Epoch 85/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1092 - accuracy: 0.5214 - val_loss: 0.1019 - val_accuracy: 0.5699
# Epoch 86/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1086 - accuracy: 0.5206 - val_loss: 0.1010 - val_accuracy: 0.5691
# Epoch 87/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1088 - accuracy: 0.5206 - val_loss: 0.1000 - val_accuracy: 0.5719
# Epoch 88/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1076 - accuracy: 0.5270 - val_loss: 0.0990 - val_accuracy: 0.5780
# Epoch 89/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1064 - accuracy: 0.5353 - val_loss: 0.0980 - val_accuracy: 0.5805
# Epoch 90/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1065 - accuracy: 0.5356 - val_loss: 0.0971 - val_accuracy: 0.5845
# Epoch 91/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1050 - accuracy: 0.5386 - val_loss: 0.0961 - val_accuracy: 0.5837
# Epoch 92/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1039 - accuracy: 0.5491 - val_loss: 0.0952 - val_accuracy: 0.5902
# Epoch 93/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1041 - accuracy: 0.5464 - val_loss: 0.0943 - val_accuracy: 0.5946
# Epoch 94/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1029 - accuracy: 0.5484 - val_loss: 0.0934 - val_accuracy: 0.5999
# Epoch 95/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1019 - accuracy: 0.5613 - val_loss: 0.0925 - val_accuracy: 0.6015
# Epoch 96/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1018 - accuracy: 0.5599 - val_loss: 0.0916 - val_accuracy: 0.6068
# Epoch 97/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1007 - accuracy: 0.5694 - val_loss: 0.0908 - val_accuracy: 0.6101
# Epoch 98/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0999 - accuracy: 0.5684 - val_loss: 0.0899 - val_accuracy: 0.6133
# Epoch 99/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0994 - accuracy: 0.5747 - val_loss: 0.0891 - val_accuracy: 0.6178
# Epoch 100/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0990 - accuracy: 0.5775 - val_loss: 0.0884 - val_accuracy: 0.6238
# Epoch 101/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0978 - accuracy: 0.5783 - val_loss: 0.0875 - val_accuracy: 0.6279
# Epoch 102/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0973 - accuracy: 0.5847 - val_loss: 0.0868 - val_accuracy: 0.6299
# Epoch 103/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0964 - accuracy: 0.5955 - val_loss: 0.0860 - val_accuracy: 0.6328
# Epoch 104/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0952 - accuracy: 0.6006 - val_loss: 0.0852 - val_accuracy: 0.6376
# Epoch 105/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0956 - accuracy: 0.6019 - val_loss: 0.0844 - val_accuracy: 0.6400
# Epoch 106/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0939 - accuracy: 0.6035 - val_loss: 0.0836 - val_accuracy: 0.6449
# Epoch 107/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0935 - accuracy: 0.6091 - val_loss: 0.0827 - val_accuracy: 0.6498
# Epoch 108/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0924 - accuracy: 0.6111 - val_loss: 0.0818 - val_accuracy: 0.6546
# Epoch 109/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0920 - accuracy: 0.6171 - val_loss: 0.0809 - val_accuracy: 0.6603
# Epoch 110/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0904 - accuracy: 0.6299 - val_loss: 0.0801 - val_accuracy: 0.6672
# Epoch 111/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0893 - accuracy: 0.6268 - val_loss: 0.0793 - val_accuracy: 0.6765
# Epoch 112/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0895 - accuracy: 0.6308 - val_loss: 0.0785 - val_accuracy: 0.6846
# Epoch 113/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0877 - accuracy: 0.6473 - val_loss: 0.0777 - val_accuracy: 0.6895
# Epoch 114/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0879 - accuracy: 0.6392 - val_loss: 0.0768 - val_accuracy: 0.6936
# Epoch 115/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0863 - accuracy: 0.6500 - val_loss: 0.0760 - val_accuracy: 0.7004
# Epoch 116/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0861 - accuracy: 0.6479 - val_loss: 0.0751 - val_accuracy: 0.7061
# Epoch 117/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0857 - accuracy: 0.6512 - val_loss: 0.0743 - val_accuracy: 0.7138
# Epoch 118/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0842 - accuracy: 0.6637 - val_loss: 0.0735 - val_accuracy: 0.7163
# Epoch 119/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0834 - accuracy: 0.6698 - val_loss: 0.0726 - val_accuracy: 0.7215
# Epoch 120/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0829 - accuracy: 0.6686 - val_loss: 0.0718 - val_accuracy: 0.7280
# Epoch 121/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0821 - accuracy: 0.6712 - val_loss: 0.0710 - val_accuracy: 0.7317
# Epoch 122/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0811 - accuracy: 0.6764 - val_loss: 0.0702 - val_accuracy: 0.7361
# Epoch 123/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0805 - accuracy: 0.6794 - val_loss: 0.0694 - val_accuracy: 0.7426
# Epoch 124/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0804 - accuracy: 0.6823 - val_loss: 0.0686 - val_accuracy: 0.7475
# Epoch 125/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0788 - accuracy: 0.6896 - val_loss: 0.0678 - val_accuracy: 0.7503
# Epoch 126/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0787 - accuracy: 0.6902 - val_loss: 0.0669 - val_accuracy: 0.7548
# Epoch 127/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0771 - accuracy: 0.7013 - val_loss: 0.0661 - val_accuracy: 0.7580
# Epoch 128/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0766 - accuracy: 0.7009 - val_loss: 0.0653 - val_accuracy: 0.7629
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-67-fc9a1395ace5> in <module>()
#      17    metrics = ['accuracy']
#      18 )
# ---> 19 model.fit(X_train, y_train, epochs=200,batch_size = 2048, validation_data=(X_test, y_test))
#      20 print("--- %s seconds ---" % (time.time() - start_time))
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1371       logs = None
#    1372       for epoch, iterator in data_handler.enumerate_epochs():
# -> 1373         self.reset_metrics()
#    1374         callbacks.on_epoch_begin(epoch)
#    1375         with data_handler.catch_stop_iteration():
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in reset_metrics(self)
#    2032     """
#    2033     for m in self.metrics:
# -> 2034       m.reset_state()
#    2035
#    2036   def train_on_batch(self,
#
# /usr/local/lib/python3.7/dist-packages/keras/metrics.py in reset_state(self)
#     265       return self.reset_states()
#     266     else:
# --> 267       backend.batch_set_value([(v, 0) for v in self.variables])
#     268
#     269   @abc.abstractmethod
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1080       # Fallback dispatch system (dispatch v1):
#    1081       try:
# -> 1082         return dispatch_target(*args, **kwargs)
#    1083       except (TypeError, ValueError):
#    1084         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.7/dist-packages/keras/backend.py in batch_set_value(tuples)
#    4017   if tf.compat.v1.executing_eagerly_outside_functions():
#    4018     for x, value in tuples:
# -> 4019       x.assign(np.asarray(value, dtype=dtype_numpy(x)))
#    4020   else:
#    4021     with get_graph().as_default():
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/resource_variable_ops.py in assign(self, value, use_locking, name, read_value)
#     932     # initialize the variable.
#     933     with _handle_graph(self.handle):
# --> 934       value_tensor = ops.convert_to_tensor(value, dtype=self.dtype)
#     935       if not self._shape.is_compatible_with(value_tensor.shape):
#     936         if self.name is None:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     181         with Trace(trace_name, **trace_kwargs):
#     182           return func(*args, **kwargs)
# --> 183       return func(*args, **kwargs)
#     184
#     185     return wrapped
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1693
#    1694     if ret is None:
# -> 1695       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1696
#    1697     if ret is NotImplemented:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/tensor_conversion_registry.py in _default_conversion_function(***failed resolving arguments***)
#      46 def _default_conversion_function(value, dtype, name, as_ref):
#      47   del as_ref  # Unused.
# ---> 48   return constant_op.constant(value, dtype, name=name)
#      49
#      50
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     266   """
#     267   return _constant_impl(value, dtype, shape, name, verify_shape=False,
# --> 268                         allow_broadcast=True)
#     269
#     270
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     277       with trace.Trace("tf.constant"):
#     278         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 279     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     280
#     281   g = ops.get_default_graph()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     302 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     303   """Creates a constant on the current device."""
# --> 304   t = convert_to_eager_tensor(value, ctx, dtype)
#     305   if shape is None:
#     306     return t
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     100       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     101   ctx.ensure_initialized()
# --> 102   return ops.EagerTensor(value, ctx.device_name, dtype)
#     103
#     104
#
# KeyboardInterrupt:

# %%
y_prob = model.predict(X_test)
print(y_prob)
y_classes = y_prob.argmax(axis=-1)
print(y_classes)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
y_classes_1=y_test.argmax(axis=-1)
mat = confusion_matrix(y_classes_1,y_classes)
print(mat)
pl= ConfusionMatrixDisplay(mat,display_labels=range(5))

# %%
import pandas as pd
FP = mat.sum(axis=0) - np.diag(mat) 
FN = mat.sum(axis=1) - np.diag(mat)
TP = np.diag(mat)
TN = mat.sum() - (FP + FN + TP)
FP = FP.astype(float)
FN = FN.astype(float)
TP = TP.astype(float)
TN = TN.astype(float)
# Sensitivity, hit rate, recall, or true positive rate
TPR = TP/(TP+FN)
# Specificity or true negative rate
TNR = TN/(TN+FP) 
# Precision or positive predictive value
PPV = TP/(TP+FP)
# Negative predictive value
NPV = TN/(TN+FN)
# Fall out or false positive rate
FPR = FP/(FP+TN)
# False negative rate
FNR = FN/(TP+FN)
# False discovery rate
FDR = FP/(TP+FP)
# Overall accuracy for each class
ACC = (TP+TN)/(TP+FP+FN+TN)
# print(TP)
# print(TN)
# print(FP)
# print(FN)
print(TPR)
print(FPR)
print(FNR)

# %%
table = pd.DataFrame({'TPR':TPR,'FPR':FPR,'FNR':FNR,'ACCURACY':ACC},index = ['Stage 1', 'Stage 2', 'Stage 3','Stage 4','Stage 5'])
table.round(3)

# %%
from sklearn.metrics import accuracy_score
print('\nAccuracy: {:.2f}\n'.format(accuracy_score(y_classes_1,y_classes)))

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
print(precision_score(y_classes_1,y_classes,average='micro'))
print(recall_score(y_classes_1,y_classes,average="micro"))
print(f1_score(y_classes_1,y_classes,average="micro"))

# %%
from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_classes_1,y_classes, target_names=['Stage 1', 'Stage 2', 'Stage 3','Stage 4','Stage 5']))

# %%
import seaborn as sn
import pandas as pd 
fig = plt.subplots(1,1, figsize = (10, 6))
target_names=['Stage 1', 'Stage 2', 'Stage 3','Stage 4','Stage 5']
df_cm = pd.DataFrame(mat,target_names,target_names)
sn.set(font_scale= 1.5)
sn.heatmap(df_cm,annot=True,annot_kws={"size":12},cmap='Blues',fmt='g')
plt.xlabel('Predictions',fontsize=18)
plt.ylabel('Actual',fontsize=18)
plt.xticks(fontsize =14)
plt.yticks(fontsize =14)
plt.savefig('MLP_ConfusionMatrix.png', dpi=100)

# %%
from google.colab import files
files.download('MLP_ConfusionMatrix.png')

# %%
import matplotlib.pyplot as plt
fig = plt.gcf()
plt.style.use('seaborn-white')
#fig = plt.subplots(1,1, figsize = (12, 8))
fig.set_size_inches(11,8, forward=True)
# fig = plt.figure()
plt.plot(history.history['loss'],'b')
plt.plot(history.history['val_loss'],'r')
plt.title('MLP',fontsize = 24)
plt.xlabel('Epochs',fontsize =22)
plt.ylabel('Loss',fontsize = 22)
plt.xticks(fontsize =18)
plt.yticks(fontsize =18)
plt.legend(['loss', 'validation loss'], loc='upper right')
plt.draw()
plt.savefig('MLP.png', dpi=300)

# %%
from google.colab import files
files.download('MLP.png')

# %%
import matplotlib.pyplot as plt 
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import roc_curve, auc, roc_auc_score
#plt.style.use('seaborn-white')

target= ['Stage 1','Stage 2','Stage 3','Stage 4','Stage 5']

# set plot figure size
fig, c_ax = plt.subplots(1,1, figsize = (12, 8))

# function for scoring roc auc score for multi-class
def multiclass_roc_auc_score(y_classes_1, y_classes, average="macro"):
    lb = LabelBinarizer()
    lb.fit(y_classes_1)
    y_test = lb.transform(y_classes_1)
    y_pred = lb.transform(y_classes)

    for (idx, c_label) in enumerate(target):
        fpr, tpr, thresholds = roc_curve(y_test[:,idx].astype(int), y_pred[:,idx])
        c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
    c_ax.plot(fpr, fpr, 'b-', label = 'Random Guessing')
    return roc_auc_score(y_test, y_pred, average=average)
print('ROC AUC score:', multiclass_roc_auc_score(y_classes_1, y_classes))
c_ax.legend(fontsize=18,)
#c_ax.legend()
c_ax.set_xlabel('False Positive Rate',fontsize = 22)
c_ax.set_ylabel('True Positive Rate',fontsize = 22)
plt.title('MLP',fontsize = 24)
plt.xticks(fontsize =18)
plt.yticks(fontsize =18)
plt.savefig('MLP_AUC.png', dpi=300)
plt.show()

# %%
from google.colab import files
files.download('MLP_AUC.png')
