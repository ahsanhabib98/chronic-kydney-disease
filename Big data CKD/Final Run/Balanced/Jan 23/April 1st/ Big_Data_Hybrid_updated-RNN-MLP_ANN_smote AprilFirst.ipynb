# %%
import pandas as pd
import numpy as np
import pandas
import numpy
import math
import warnings
import time
import matplotlib.pyplot as plt

from collections import Counter
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV
from sklearn.utils import shuffle
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor
from sklearn.metrics import roc_curve, auc, accuracy_score,roc_auc_score,mean_absolute_error,r2_score

from scipy import stats
import pickle

warnings.filterwarnings('ignore')

# %%
import h5py as h5
import scipy.io as sio
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from os import listdir
from tensorflow.keras.preprocessing import sequence
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten, Embedding, Dropout, Activation, Reshape
#from tensorflow.keras.layers import Dense, Conv1D, MaxPooling1D, GlobalAveragePooling1D, TimeDistributed
from tensorflow.keras.layers import LSTM
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
#dataset = pd.read_csv('sample_data/data_CKD_MI.csv')

# %%
dataset = pd.read_csv('sample_data/data_CKD_bigdata_refined.csv')
print(dataset.shape)
#df = dataset.dropna()
#print(df.shape)
#df.describe()
# Out:
# (1000000, 28)

# %%
#dataset = dataset.head(10000)
# dataset

# %%
dataset.shape
# Out:
# (1000000, 28)

# %%
dataset.isnull().sum()
# Out:
# sex                      0
# age                      0
# height                   0
# weight                   0
# waist                    0
# vision_left              0
# vision_right             0
# listen_left              0
# listen_right             0
# BP_HIGH                  0
# BP_LWST                  0
# BLDS                     0
# TOT_CHOLE                0
# TRIGLYCERIDE             0
# HDL_CHOLE                0
# LDL_CHOLE                0
# HMG                      0
# OLIG_PROTE_CD            0
# CREATININE               0
# SGOT_AST                 0
# SGPT_ALT                 0
# GAMMA_GTP                0
# SMK_STAT_TYPE_RSPS_CD    0
# DRINK_OR_NOT             0
# MOUTH_CHECK              0
# BMI                      0
# GFR                      0
# stage                    0
# dtype: int64

# %%
# dataset = dataset[dataset[ 'CREATININE ']<=15]

# %%
dataset[['stage']] = dataset[['stage']].replace(to_replace={1:0,2:1,3:2,4:3,5:4})
dataset
# Out:
#         sex  age  height  weight  waist  vision_left  vision_right  \
# 0         1   40     170      75   90.0          1.0           1.0
# 1         1   35     180      80   89.0          0.9           1.2
# 2         1   45     165      75   91.0          1.2           1.5
# 3         1   55     175      80   91.0          1.5           1.2
# 4         1   55     165      60   80.0          1.0           1.2
# ...     ...  ...     ...     ...    ...          ...           ...
# 999995    1   50     175      80   92.1          1.5           1.5
# 999996    1   40     170      75   86.0          1.0           1.5
# 999997    2   45     155      50   68.0          1.0           0.7
# 999998    1   30     175      60   72.0          1.5           1.0
# 999999    1   55     160      70   90.5          1.0           1.5
#
#         listen_left  listen_right  BP_HIGH  ...  CREATININE  SGOT_AST  \
# 0               1.0           1.0    120.0  ...         1.0      21.0
# 1               1.0           1.0    130.0  ...         0.9      20.0
# 2               1.0           1.0    120.0  ...         0.9      47.0
# 3               1.0           1.0    145.0  ...         1.1      29.0
# 4               1.0           1.0    138.0  ...         0.8      19.0
# ...             ...           ...      ...  ...         ...       ...
# 999995          1.0           1.0    114.0  ...         1.0      26.0
# 999996          1.0           1.0    119.0  ...         1.1      14.0
# 999997          1.0           1.0    110.0  ...         0.8      30.0
# 999998          1.0           1.0    119.0  ...         0.8      21.0
# 999999          1.0           1.0    133.0  ...         0.9      24.0
#
#         SGPT_ALT  GAMMA_GTP  SMK_STAT_TYPE_RSPS_CD  DRINK_OR_NOT  MOUTH_CHECK  \
# 0           35.0       40.0                    1.0           1.0            1
# 1           36.0       27.0                    3.0           0.0            1
# 2           32.0       68.0                    1.0           0.0            0
# 3           34.0       18.0                    1.0           0.0            1
# 4           12.0       25.0                    1.0           0.0            1
# ...          ...        ...                    ...           ...          ...
# 999995      36.0       27.0                    1.0           0.0            0
# 999996      17.0       15.0                    1.0           0.0            0
# 999997      27.0       17.0                    3.0           1.0            0
# 999998      14.0       17.0                    1.0           0.0            0
# 999999      43.0       36.0                    3.0           1.0            0
#
#               BMI         GFR  stage
# 0       25.951557   86.886038      1
# 1       24.691358  100.644197      0
# 2       27.548209   95.928640      0
# 3       26.122449   73.203730      1
# 4       22.038567  105.714492      0
# ...           ...         ...    ...
# 999995  26.122449   83.237802      1
# 999996  25.951557   77.836416      1
# 999997  20.811655   81.542158      1
# 999998  19.591837  118.695643      0
# 999999  27.343750   92.279348      0
#
# [1000000 rows x 28 columns]

# %%
from sklearn.model_selection import train_test_split    
from sklearn.preprocessing import MinMaxScaler
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
import keras.layers
from tensorflow.keras.utils import to_categorical
from imblearn.over_sampling import SMOTE

# %%
import pandas as pd
import numpy as np
from google.colab import files
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import RandomOverSampler
#from imblearn.under_sampling import RandomUnderSampler
from collections import Counter
from sklearn import metrics
import math
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error

# %%
from sklearn.model_selection import train_test_split    
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
from collections import Counter
#Data preprocessing
X = dataset.iloc[:,:-1].values
y = dataset.iloc[:,-1].values

# %%
np.unique(y)
# Out:
# array([0, 1, 2, 3, 4])

# %%
from imblearn.over_sampling import SMOTE
counter = Counter(y)
print('Before',counter)
# oversampling the train dataset using SMOTE
smt = SMOTE()
#X_train, y_train = smt.fit_resample(X_train, y_train)
X_sm, y_sm = smt.fit_resample(X, y)

counter = Counter(y_sm)
print('After',counter)
# Out:
# Before Counter({1: 486184, 0: 475386, 2: 36377, 4: 1027, 3: 1026})
# After Counter({1: 486184, 0: 486184, 2: 486184, 4: 486184, 3: 486184})

# %%
X_train, X_test, y_train, y_test = train_test_split(X_sm,y_sm, test_size=0.2, random_state = 2)

# %%
print(X_test[0])
# Out:
# [  2.          48.01347329 158.49326335  50.          70.30134733
#    1.           1.           1.           1.          99.10943131
#   61.39730534 111.79461068 240.98652671 228.42425193  45.68517938
#  149.09595801  13.61784427   1.           1.23013473  14.30134733
#   11.69865267  26.58922136   1.           0.69865267   1.
#   19.91709649  49.17912919]

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test  = scaler.transform(X_test)

# %%
X_test[0]
# Out:
# array([1.        , 0.35405344, 0.47488772, 0.2173913 , 0.03960843,
#        0.09183673, 0.09183673, 0.04009897, 0.04139665, 0.19120666,
#        0.20256326, 0.10495116, 0.09117827, 0.02396715, 0.00551057,
#        0.40486903, 0.5438726 , 0.0497523 , 0.01154377, 0.00160171,
#        0.00230973, 0.0256405 , 0.08528991, 0.52530636, 1.        ,
#        0.22361448, 0.03611951])

# %%
import pickle
pickle.dump(scaler, open('ckd_hybrid_scaler.pkl', 'wb'))

# %%
xg_reg = XGBRegressor()
xg_reg.fit(X_train, y_train )
y_train_hat = xg_reg.predict(X_train)
train_r2 = metrics.r2_score(y_true=y_train, y_pred=y_train_hat)
train_rmse = np.sqrt(mean_squared_error(y_train , y_train_hat))
print ('R2: ',train_r2)
print ('RMSE: ', train_rmse)
# Out:
# [22:33:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# R2:  0.9906093812931553
# RMSE:  0.13705672031865368

# %%
# from imblearn.combine import SMOTEENN
# counter = Counter(y)
# print('Before',counter)
# # oversampling the train dataset using SMOTE + ENN
# smenn = SMOTEENN()
# X_smenn, y_smenn = smenn.fit_resample(X,y)
# counter = Counter(y_smenn)
# print('After',counter)

# %%
#X_train,X_test,y_train,y_test=train_test_split(X_smenn, y_smenn, train_size=0.8, stratify = y_smenn, random_state=100)

# %%
print(X_train.shape,y_train.shape)
y_train = to_categorical(y_train,num_classes = 5,dtype="uint8")
print(y_train.shape)
y_test = to_categorical(y_test,num_classes = 5,dtype ="uint8")
print(y_test.shape)
# Out:
# (1944736, 27) (1944736,)
# (1944736, 5)
# (486184, 5)

# %%
X_train = np.reshape(X_train,(X_train.shape[0],X_train.shape[1],1))
X_test = np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))
print(X_train.shape)
print(X_test.shape)
# Out:
# (1944736, 27, 1)
# (486184, 27, 1)

# %%
# # get the model SimpleRNN
from keras.layers import Dense, SimpleRNN
def evaluate_model_SimpleRNN(X_train, X_val, y_train, y_val):
  model = SimpleRNN
  timesteps=125
  dims=4
  model = Sequential()
  model.add(SimpleRNN(units=32, input_shape=(X_train.shape[1],1), activation="relu"))
  model.add(Dense(256, kernel_initializer='he_uniform', activation='relu'))
  model.add(Dense(128, kernel_initializer='he_uniform', activation='relu'))
  model.add(Dense(64, kernel_initializer='he_uniform', activation='relu'))
  model.add(Dense(5, kernel_initializer='he_uniform'))
  model.compile(loss='mse', optimizer=Adam(lr = 0.001), metrics=['accuracy'])
  history = model.fit(X_train, y_train, validation_data = (X_test,y_test), epochs=200, batch_size=5096, verbose=1)
  return history, model

# %%
n_folds = 1
cv_scores, model_history = list(), list()
model = tf.keras.Sequential()
history, model= evaluate_model_SimpleRNN(X_train, X_test, y_train, y_test)
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
# Out:
# Epoch 1/200
# 382/382 [==============================] - 8s 17ms/step - loss: 0.0456 - accuracy: 0.8690 - val_loss: 0.0110 - val_accuracy: 0.9760
# Epoch 2/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0090 - accuracy: 0.9776 - val_loss: 0.0067 - val_accuracy: 0.9860
# Epoch 3/200
# 382/382 [==============================] - 6s 17ms/step - loss: 0.0067 - accuracy: 0.9826 - val_loss: 0.0055 - val_accuracy: 0.9881
# Epoch 4/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0054 - accuracy: 0.9859 - val_loss: 0.0044 - val_accuracy: 0.9891
# Epoch 5/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0051 - accuracy: 0.9855 - val_loss: 0.0043 - val_accuracy: 0.9874
# Epoch 6/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0047 - accuracy: 0.9865 - val_loss: 0.0036 - val_accuracy: 0.9908
# Epoch 7/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0038 - accuracy: 0.9894 - val_loss: 0.0031 - val_accuracy: 0.9914
# Epoch 8/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0038 - accuracy: 0.9888 - val_loss: 0.0035 - val_accuracy: 0.9886
# Epoch 9/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0033 - accuracy: 0.9904 - val_loss: 0.0024 - val_accuracy: 0.9935
# Epoch 10/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0033 - accuracy: 0.9911 - val_loss: 0.0025 - val_accuracy: 0.9933
# Epoch 11/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0029 - accuracy: 0.9919 - val_loss: 0.0034 - val_accuracy: 0.9881
# Epoch 12/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0029 - accuracy: 0.9918 - val_loss: 0.0031 - val_accuracy: 0.9932
# Epoch 13/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0022 - accuracy: 0.9942 - val_loss: 0.0027 - val_accuracy: 0.9926
# Epoch 14/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0027 - accuracy: 0.9925 - val_loss: 0.0025 - val_accuracy: 0.9931
# Epoch 15/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0023 - accuracy: 0.9938 - val_loss: 0.0017 - val_accuracy: 0.9959
# Epoch 16/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0023 - accuracy: 0.9936 - val_loss: 0.0035 - val_accuracy: 0.9907
# Epoch 17/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0024 - accuracy: 0.9934 - val_loss: 0.0013 - val_accuracy: 0.9968
# Epoch 18/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0019 - accuracy: 0.9950 - val_loss: 0.0012 - val_accuracy: 0.9970
# Epoch 19/200
# 382/382 [==============================] - 7s 17ms/step - loss: 0.0025 - accuracy: 0.9932 - val_loss: 0.0019 - val_accuracy: 0.9958
# Epoch 20/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0021 - accuracy: 0.9946 - val_loss: 0.0017 - val_accuracy: 0.9955
# Epoch 21/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0021 - accuracy: 0.9946 - val_loss: 0.0012 - val_accuracy: 0.9974
# Epoch 22/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0021 - accuracy: 0.9946 - val_loss: 0.0012 - val_accuracy: 0.9974
# Epoch 23/200
# 382/382 [==============================] - 6s 17ms/step - loss: 0.0022 - accuracy: 0.9946 - val_loss: 0.0012 - val_accuracy: 0.9973
# Epoch 24/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0020 - accuracy: 0.9944 - val_loss: 0.0015 - val_accuracy: 0.9963
# Epoch 25/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0017 - accuracy: 0.9955 - val_loss: 0.0038 - val_accuracy: 0.9869
# Epoch 26/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0018 - accuracy: 0.9951 - val_loss: 0.0022 - val_accuracy: 0.9939
# Epoch 27/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0019 - accuracy: 0.9948 - val_loss: 9.8521e-04 - val_accuracy: 0.9977
# Epoch 28/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0016 - accuracy: 0.9961 - val_loss: 0.0093 - val_accuracy: 0.9726
# Epoch 29/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0021 - accuracy: 0.9944 - val_loss: 0.0010 - val_accuracy: 0.9981
# Epoch 30/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0015 - accuracy: 0.9960 - val_loss: 0.0027 - val_accuracy: 0.9918
# Epoch 31/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0043 - accuracy: 0.9877 - val_loss: 0.0064 - val_accuracy: 0.9777
# Epoch 32/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0028 - accuracy: 0.9915 - val_loss: 0.0019 - val_accuracy: 0.9948
# Epoch 33/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0022 - accuracy: 0.9938 - val_loss: 0.0014 - val_accuracy: 0.9964
# Epoch 34/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0019 - accuracy: 0.9951 - val_loss: 0.0013 - val_accuracy: 0.9969
# Epoch 35/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0021 - accuracy: 0.9950 - val_loss: 0.0014 - val_accuracy: 0.9959
# Epoch 36/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0014 - accuracy: 0.9967 - val_loss: 0.0084 - val_accuracy: 0.9765
# Epoch 37/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0018 - accuracy: 0.9955 - val_loss: 0.0057 - val_accuracy: 0.9837
# Epoch 38/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0016 - accuracy: 0.9960 - val_loss: 9.0726e-04 - val_accuracy: 0.9981
# Epoch 39/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0019 - accuracy: 0.9952 - val_loss: 0.0016 - val_accuracy: 0.9976
# Epoch 40/200
# 382/382 [==============================] - 6s 16ms/step - loss: 9.8328e-04 - accuracy: 0.9979 - val_loss: 7.7243e-04 - val_accuracy: 0.9983
# Epoch 41/200
# 382/382 [==============================] - 6s 17ms/step - loss: 0.0018 - accuracy: 0.9956 - val_loss: 9.1872e-04 - val_accuracy: 0.9979
# Epoch 42/200
# 382/382 [==============================] - 6s 17ms/step - loss: 0.0018 - accuracy: 0.9956 - val_loss: 8.5562e-04 - val_accuracy: 0.9984
# Epoch 43/200
# 382/382 [==============================] - 6s 17ms/step - loss: 0.0020 - accuracy: 0.9950 - val_loss: 7.2959e-04 - val_accuracy: 0.9986
# Epoch 44/200
# 382/382 [==============================] - 6s 17ms/step - loss: 0.0014 - accuracy: 0.9966 - val_loss: 0.0012 - val_accuracy: 0.9965
# Epoch 45/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0018 - accuracy: 0.9957 - val_loss: 8.1144e-04 - val_accuracy: 0.9981
# Epoch 46/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0017 - accuracy: 0.9958 - val_loss: 7.4496e-04 - val_accuracy: 0.9987
# Epoch 47/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0010 - accuracy: 0.9975 - val_loss: 0.0012 - val_accuracy: 0.9968
# Epoch 48/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0016 - accuracy: 0.9958 - val_loss: 5.4435e-04 - val_accuracy: 0.9989
# Epoch 49/200
# 382/382 [==============================] - 7s 17ms/step - loss: 0.0019 - accuracy: 0.9954 - val_loss: 7.2639e-04 - val_accuracy: 0.9983
# Epoch 50/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0021 - accuracy: 0.9946 - val_loss: 0.0023 - val_accuracy: 0.9927
# Epoch 51/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0018 - accuracy: 0.9953 - val_loss: 6.6927e-04 - val_accuracy: 0.9989
# Epoch 52/200
# 382/382 [==============================] - 6s 17ms/step - loss: 9.2664e-04 - accuracy: 0.9977 - val_loss: 8.0053e-04 - val_accuracy: 0.9981
# Epoch 53/200
# 382/382 [==============================] - 6s 17ms/step - loss: 0.0011 - accuracy: 0.9973 - val_loss: 0.0066 - val_accuracy: 0.9805
# Epoch 54/200
# 382/382 [==============================] - 6s 17ms/step - loss: 0.0015 - accuracy: 0.9962 - val_loss: 4.9222e-04 - val_accuracy: 0.9991
# Epoch 55/200
# 382/382 [==============================] - 6s 17ms/step - loss: 0.0012 - accuracy: 0.9972 - val_loss: 6.5395e-04 - val_accuracy: 0.9988
# Epoch 56/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0018 - accuracy: 0.9954 - val_loss: 0.0041 - val_accuracy: 0.9851
# Epoch 57/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0017 - accuracy: 0.9957 - val_loss: 5.8770e-04 - val_accuracy: 0.9989
# Epoch 58/200
# 382/382 [==============================] - 6s 16ms/step - loss: 6.2403e-04 - accuracy: 0.9986 - val_loss: 5.0159e-04 - val_accuracy: 0.9992
# Epoch 59/200
# 382/382 [==============================] - 6s 17ms/step - loss: 7.4712e-04 - accuracy: 0.9983 - val_loss: 3.2884e-04 - val_accuracy: 0.9993
# Epoch 60/200
# 382/382 [==============================] - 6s 17ms/step - loss: 0.0025 - accuracy: 0.9930 - val_loss: 5.6501e-04 - val_accuracy: 0.9991
# Epoch 61/200
# 382/382 [==============================] - 6s 16ms/step - loss: 5.6493e-04 - accuracy: 0.9987 - val_loss: 3.2213e-04 - val_accuracy: 0.9994
# Epoch 62/200
# 382/382 [==============================] - 6s 16ms/step - loss: 6.5404e-04 - accuracy: 0.9985 - val_loss: 3.1876e-04 - val_accuracy: 0.9994
# Epoch 63/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0010 - accuracy: 0.9973 - val_loss: 0.0012 - val_accuracy: 0.9964
# Epoch 64/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0015 - accuracy: 0.9960 - val_loss: 4.8809e-04 - val_accuracy: 0.9991
# Epoch 65/200
# 382/382 [==============================] - 6s 17ms/step - loss: 0.0021 - accuracy: 0.9944 - val_loss: 0.0016 - val_accuracy: 0.9968
# Epoch 66/200
# 382/382 [==============================] - 6s 17ms/step - loss: 0.0011 - accuracy: 0.9971 - val_loss: 4.3783e-04 - val_accuracy: 0.9992
# Epoch 67/200
# 382/382 [==============================] - 6s 17ms/step - loss: 0.0011 - accuracy: 0.9972 - val_loss: 4.1488e-04 - val_accuracy: 0.9991
# Epoch 68/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0013 - accuracy: 0.9964 - val_loss: 4.6503e-04 - val_accuracy: 0.9990
# Epoch 69/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0012 - accuracy: 0.9966 - val_loss: 0.0020 - val_accuracy: 0.9936
# Epoch 70/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0011 - accuracy: 0.9972 - val_loss: 3.4960e-04 - val_accuracy: 0.9992
# Epoch 71/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.
# 382/382 [==============================] - 6s 17ms/step - loss: 0.0011 - accuracy: 0.9970 - val_loss: 2.2407e-04 - val_accuracy: 0.9995
# Epoch 140/200
# 382/382 [==============================] - 6s 16ms/step - loss: 6.8612e-04 - accuracy: 0.9982 - val_loss: 1.8494e-04 - val_accuracy: 0.9995
# Epoch 141/200
# 382/382 [==============================] - 6s 17ms/step - loss: 0.0013 - accuracy: 0.9965 - val_loss: 0.0042 - val_accuracy: 0.9879
# Epoch 142/200
# 382/382 [==============================] - 6s 17ms/step - loss: 0.0022 - accuracy: 0.9934 - val_loss: 5.1666e-04 - val_accuracy: 0.9987
# Epoch 143/200
# 382/382 [==============================] - 6s 17ms/step - loss: 3.5054e-04 - accuracy: 0.9992 - val_loss: 2.5105e-04 - val_accuracy: 0.9994
# Epoch 144/200
# 382/382 [==============================] - 6s 17ms/step - loss: 9.5457e-04 - accuracy: 0.9972 - val_loss: 1.9008e-04 - val_accuracy: 0.9995
# Epoch 145/200
# 382/382 [==============================] - 6s 16ms/step - loss: 5.6845e-04 - accuracy: 0.9984 - val_loss: 2.6710e-04 - val_accuracy: 0.9995
# Epoch 146/200
# 382/382 [==============================] - 6s 16ms/step - loss: 8.0909e-04 - accuracy: 0.9978 - val_loss: 1.6861e-04 - val_accuracy: 0.9996
# Epoch 147/200
# 382/382 [==============================] - 6s 17ms/step - loss: 0.0016 - accuracy: 0.9956 - val_loss: 3.4429e-04 - val_accuracy: 0.9991
# Epoch 148/200
# 382/382 [==============================] - 6s 16ms/step - loss: 8.3365e-04 - accuracy: 0.9977 - val_loss: 1.7898e-04 - val_accuracy: 0.9996
# Epoch 149/200
# 382/382 [==============================] - 6s 16ms/step - loss: 7.0647e-04 - accuracy: 0.9979 - val_loss: 7.0315e-04 - val_accuracy: 0.9985
# Epoch 150/200
# 382/382 [==============================] - 6s 16ms/step - loss: 3.6134e-04 - accuracy: 0.9990 - val_loss: 1.4306e-04 - val_accuracy: 0.9997
# Epoch 151/200
# 382/382 [==============================] - 6s 16ms/step - loss: 5.7138e-04 - accuracy: 0.9985 - val_loss: 2.7522e-04 - val_accuracy: 0.9993
# Epoch 152/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0012 - accuracy: 0.9966 - val_loss: 1.7117e-04 - val_accuracy: 0.9996
# Epoch 153/200
# 382/382 [==============================] - 6s 16ms/step - loss: 4.7316e-04 - accuracy: 0.9987 - val_loss: 1.8335e-04 - val_accuracy: 0.9995
# Epoch 154/200
# 382/382 [==============================] - 6s 16ms/step - loss: 1.7318e-04 - accuracy: 0.9996 - val_loss: 1.6904e-04 - val_accuracy: 0.9996
# Epoch 155/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0025 - accuracy: 0.9929 - val_loss: 0.0115 - val_accuracy: 0.9659
# Epoch 156/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0013 - accuracy: 0.9961 - val_loss: 3.0000e-04 - val_accuracy: 0.9993
# Epoch 157/200
# 382/382 [==============================] - 6s 16ms/step - loss: 2.4259e-04 - accuracy: 0.9994 - val_loss: 2.2713e-04 - val_accuracy: 0.9994
# Epoch 158/200
# 382/382 [==============================] - 6s 16ms/step - loss: 0.0012 - accuracy: 0.9967 - val_loss: 2.5095e-04 - val_accuracy: 0.9994
# Epoch 159/200
# 382/382 [==============================] - 6s 16ms/step - loss: 7.5982e-04 - accuracy: 0.9980 - val_loss: 0.0015 - val_accuracy: 0.9959
# Epoch 160/200
# 382/382 [==============================] - 7s 17ms/step - loss: 2.0896e-04 - accuracy: 0.9995 - val_loss: 1.3872e-04 - val_accuracy: 0.9997
# Epoch 161/200
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import pickle
pickle.dump(model, open('ckd_hybrid_model.pkl', 'wb'))
# Out:
# INFO:tensorflow:Assets written to: ram://c2362fb6-af95-49ec-acf5-fa6201c1ee5c/assets

# %%
y_prob = model.predict(X_test)
print(y_prob)
y_classes = y_prob.argmax(axis=-1)
print(y_classes)
# Out:
# [[-6.8441033e-05 -9.2640473e-04  1.0041137e+00  1.0630116e-04
#   -1.2342632e-03]
#  [-9.0733171e-05 -2.0843293e-03  1.0025508e+00  9.4744191e-04
#   -2.6735663e-04]
#  [ 1.0046909e+00 -7.3213829e-04 -9.5150620e-04 -2.4165586e-04
#   -1.2018681e-03]
#  ...
#  [ 1.0020359e+00  1.1301194e-03  6.1874837e-04 -4.0815398e-04
#   -1.3071150e-03]
#  [-2.4338067e-04 -8.1996573e-04  1.0049660e+00 -1.2542941e-03
#   -4.3502450e-04]
#  [-4.5401752e-03  2.4952744e-03  1.0004095e+00 -3.4239627e-03
#    5.1909387e-03]]
# [2 2 0 ... 0 2 2]

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
y_classes_1=y_test.argmax(axis=-1)
mat = confusion_matrix(y_classes_1,y_classes)
print(mat)
pl= ConfusionMatrixDisplay(mat,display_labels=range(5))
# Out:
# [[97231     8     0     0    17]
#  [    1 97253     3     0    16]
#  [    0     0 97291    62     0]
#  [    0     0     0 97263    11]
#  [   11    32     0     0 96985]]

# %%
import pandas as pd
FP = mat.sum(axis=0) - np.diag(mat) 
FN = mat.sum(axis=1) - np.diag(mat)
TP = np.diag(mat)
TN = mat.sum() - (FP + FN + TP)
FP = FP.astype(float)
FN = FN.astype(float)
TP = TP.astype(float)
TN = TN.astype(float)
# Sensitivity, hit rate, recall, or true positive rate
TPR = TP/(TP+FN)
# Specificity or true negative rate
TNR = TN/(TN+FP) 
# Precision or positive predictive value
PPV = TP/(TP+FP)
# Negative predictive value
NPV = TN/(TN+FN)
# Fall out or false positive rate
FPR = FP/(FP+TN)
# False negative rate
FNR = FN/(TP+FN)
# False discovery rate
FDR = FP/(TP+FP)
# Overall accuracy for each class
ACC = (TP+TN)/(TP+FP+FN+TN)
# print(TP)
# print(TN)
# print(FP)
# print(FN)
print(TPR)
print(FPR)
print(FNR)
# Out:
# [0.99974295 0.99979439 0.99936314 0.99988692 0.99955683]
# [3.08540398e-05 1.02851295e-04 7.71543421e-06 1.59419917e-04
#  1.13065198e-04]
# [0.00025705 0.00020561 0.00063686 0.00011308 0.00044317]

# %%
table = pd.DataFrame({'TPR':TPR,'FPR':FPR,'FNR':FNR,'ACCURACY':ACC},index = ['Stage 1', 'Stage 2', 'Stage 3','Stage 4','Stage 5'])
table.round(3)
# Out:
#            TPR  FPR    FNR  ACCURACY
# Stage 1  1.000  0.0  0.000       1.0
# Stage 2  1.000  0.0  0.000       1.0
# Stage 3  0.999  0.0  0.001       1.0
# Stage 4  1.000  0.0  0.000       1.0
# Stage 5  1.000  0.0  0.000       1.0

# %%
from sklearn.metrics import accuracy_score
print('\nAccuracy: {:.2f}\n'.format(accuracy_score(y_classes_1,y_classes)))
# Out:
# Accuracy: 1.00

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
print(precision_score(y_classes_1,y_classes,average='micro'))
print(recall_score(y_classes_1,y_classes,average="micro"))
print(f1_score(y_classes_1,y_classes,average="micro"))
# Out:
# 0.9996688496536291
# 0.9996688496536291
# 0.9996688496536291

# %%
from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_classes_1,y_classes, target_names=['Stage 1', 'Stage 2', 'Stage 3','Stage 4','Stage 5']))
# Out:
# Classification Report
#
#               precision    recall  f1-score   support
#
#      Stage 1       1.00      1.00      1.00     97256
#      Stage 2       1.00      1.00      1.00     97273
#      Stage 3       1.00      1.00      1.00     97353
#      Stage 4       1.00      1.00      1.00     97274
#      Stage 5       1.00      1.00      1.00     97028
#
#     accuracy                           1.00    486184
#    macro avg       1.00      1.00      1.00    486184
# weighted avg       1.00      1.00      1.00    486184

# %%
import seaborn as sn
import pandas as pd 
fig = plt.subplots(1,1, figsize = (10, 6))
target_names=['Stage 1', 'Stage 2', 'Stage 3','Stage 4','Stage 5']
df_cm = pd.DataFrame(mat,target_names,target_names)
sn.set(font_scale= 1.5)
sn.heatmap(df_cm,annot=True,annot_kws={"size":12},cmap='Blues',fmt='g')
plt.xlabel('Predictions',fontsize=18)
plt.ylabel('Actual',fontsize=18)
plt.xticks(fontsize =14)
plt.yticks(fontsize =14)
plt.savefig('RNN-MLP_ConfusionMatrix.png', dpi=100)

# %%
from google.colab import files
files.download('RNN-MLP_ConfusionMatrix.png')

# %%
import matplotlib.pyplot as plt
fig = plt.gcf()
plt.style.use('seaborn-white')
#fig = plt.subplots(1,1, figsize = (12, 8))
fig.set_size_inches(11,8, forward=True)
# fig = plt.figure()
plt.plot(history.history['loss'],'b')
plt.plot(history.history['val_loss'],'r')
plt.title('RNN-MLP',fontsize = 24)
plt.xlabel('Epochs',fontsize =22)
plt.ylabel('Loss',fontsize = 22)
plt.xticks(fontsize =18)
plt.yticks(fontsize =18)
plt.legend(['loss', 'validation loss'], loc='upper right')
plt.draw()
plt.savefig('RNN-MLP.png', dpi=300)

# %%
from google.colab import files
files.download('RNN-MLP.png')

# %%
import matplotlib.pyplot as plt 
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import roc_curve, auc, roc_auc_score
#plt.style.use('seaborn-white')

target= ['Stage 1','Stage 2','Stage 3','Stage 4','Stage 5']

# set plot figure size
fig, c_ax = plt.subplots(1,1, figsize = (12, 8))

# function for scoring roc auc score for multi-class
def multiclass_roc_auc_score(y_classes_1, y_classes, average="macro"):
    lb = LabelBinarizer()
    lb.fit(y_classes_1)
    y_test = lb.transform(y_classes_1)
    y_pred = lb.transform(y_classes)

    for (idx, c_label) in enumerate(target):
        fpr, tpr, thresholds = roc_curve(y_test[:,idx].astype(int), y_pred[:,idx])
        c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
    c_ax.plot(fpr, fpr, 'b-', label = 'Random Guessing')
    return roc_auc_score(y_test, y_pred, average=average)
print('ROC AUC score:', multiclass_roc_auc_score(y_classes_1, y_classes))
c_ax.legend(fontsize=18,)
#c_ax.legend()
c_ax.set_xlabel('False Positive Rate',fontsize = 22)
c_ax.set_ylabel('True Positive Rate',fontsize = 22)
plt.title('RNN-MLP',fontsize = 24)
plt.xticks(fontsize =18)
plt.yticks(fontsize =18)
plt.savefig('RNN-MLP_AUC.png', dpi=300)
plt.show()
# Out:
# ROC AUC score: 0.9997930322369459

# %%
from google.colab import files
files.download('RNN-MLP_AUC.png')
