# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

# %%
objects = ('Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp')
y_pos = np.arange(len(objects))
performance = [10,8,6,4,2,1]

# %%
y_pos
print(y_pos)
performance

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# data=pd.read_csv('/content/sample_data/RFE Accuracy.csv')

# %%
data=pd.read_csv('/content/sample_data/ComputationTime.csv')

# %%
data
# Out:
#             Algorithm     WFS    CFS    RFE  Lasso  Boruta
# 0                 ANN  10.880  10.54  10.89  10.90   10.83
# 1                LSTM  29.056  44.88  47.60  24.18   85.54
# 2  Bidirectional LSTM  87.580  46.00  46.95  27.77   87.04
# 3                 GRU  63.290  47.06  46.60  30.94   65.97
# 4   Bidirectional GRU  90.630  51.06  91.44  60.88   50.18
# 5          Simple RNN  42.190  21.68  15.00  21.81   21.10
# 6                 MLP  11.060  11.04   9.50  11.04   12.50

# %%
y_pos = np.arange(len(data['Algorithm']))

# %%
b

# %%
A = data['WFS']

# %%
barWidth = 0.25
fig = plt.subplots(figsize =(15, 10))
br1 = np.arange(len(data['WFS']))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]
br5 = [[x + barWidth for x in br4]]

# %%
plt.rcParams["figure.figsize"] = [18,10]
barWidth = 0.15
# fig = plt.subplots(figsize =(18, 10))
br1 = np.arange(len(data['WFS']))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]
br5 = [x + barWidth for x in br4]
# Make the plot
plt.bar(br1, data['WFS'], color ='gray', width = barWidth,
        edgecolor ='grey', label ='WFS')
plt.bar(br2, data['CFS'], color ='gainsboro', width = barWidth,
        edgecolor ='grey', label ='CFS')
plt.bar(br3, data['RFE'], color ='tan', width = barWidth,
        edgecolor ='grey', label ='RFE')
plt.bar(br4, data['Lasso'], color ='moccasin', width = barWidth,
        edgecolor ='grey', label ='Lasso')
plt.bar(br5, data['Boruta'], color ='slategrey', width = barWidth,
        edgecolor ='grey', label ='Boruta')

# Adding Xticks
plt.xlabel('Models', fontsize = 20)
plt.ylabel('Computation time', fontsize = 20)
plt.xticks([r + barWidth for r in range(len(data['WFS']))],
        ['ANN', 'LSTM', 'BiLSTM', 'GRU', 'BiGRU','SimpleRNN','MLP'],fontsize = 15)
plt.yticks(fontsize = 15)
# plt.title('Computation Time',fontweight ='bold', fontsize = 20)
 
plt.legend(fontsize = 16)
plt.savefig('Computation Time.png')
plt.show()

# %%
from google.colab import files
files.download('Computation Time.png')

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.plot(a11['Calcium'],a11['open_prob'],label='P=0.033µM')
ax.plot(a12['Calcium'],a12['open_prob'],label='P=0.1µM')
ax.plot(a13['Calcium'],a13['open_prob'],label='P=10µM')
ax.legend()
plt.grid()
ax.set_xscale("log")
plt.xlabel('calcium')
plt.ylabel('Po')
plt.title('open probability of IP3R channel in wild type cells')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.bar(data['Algorithm'], data['Boruta'], align='center', alpha=0.5,label='Boruta')
ax.bar(data['Algorithm'], data['WFS'], align='center', alpha=0.5,label='WFS')
ax.bar(data['Algorithm'], data['CFS'], align='center', alpha=0.5,label='WFS')
plt.xticks(data['Algorithm'])
ax.legend()
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
File1=pd.read_csv('/content/sample_data/Time_FS.csv')

# %%
File1
# Out:
#   Algorithm    ANN    LSTM  ...  Bidirectional GRU  Simple RNN    MLP
# 0       WFS  10.88  29.056  ...              90.63       42.19  11.06
# 1       CFS  10.54  44.880  ...              51.06       21.68  11.04
# 2       RFE  10.89  47.600  ...              91.44       15.00   9.50
# 3     Lasso  10.90  24.180  ...              60.88       21.81  11.04
# 4    Boruta  10.83  85.540  ...              50.18       21.10  12.50
#
# [5 rows x 8 columns]

# %%
n_groups = 2

# %%
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

# %%
x=

# %%
rects1 = plt.bar(index, File1['WFS'], bar_width,
alpha=opacity,
color='b',
label='ANN')
rects2 = plt.bar(index+bar_width, File1['CFS'], bar_width,
alpha=opacity,
color='g',
label='CFS')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-28beb5bad329> in <module>()
#       2 alpha=opacity,
#       3 color='b',
# ----> 4 label='CFS')
#       5 rects2 = plt.bar(index+bar_width, File1['CFS'], bar_width,
#       6 alpha=opacity,
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2407     return gca().bar(
#    2408         x, height, width=width, bottom=bottom, align=align,
# -> 2409         **({"data": data} if data is not None else {}), **kwargs)
#    2410
#    2411
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# data to plot
n_groups = 4
means_frank = (90, 55, 40, 65)
means_guido = (85, 62, 54, 20)

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rects1 = plt.bar(index, means_frank, bar_width,
alpha=opacity,
color='b',
label='Frank')

rects2 = plt.bar(index + bar_width, means_guido, bar_width,
alpha=opacity,
color='g',
label='Guido')

plt.xlabel('Person')
plt.ylabel('Scores')
plt.title('Scores by person')
plt.xticks(index + bar_width, ('A', 'B', 'C', 'D'))
plt.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# data to plot
n_groups = 4
means_frank = (90, 55, 40, 65)
means_guido = (85, 62, 54, 20)

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rects1 = plt.bar(index, means_frank, bar_width,
alpha=opacity,
color='b',
label='Frank')

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# set width of bar
barWidth = 0.25
fig = plt.subplots(figsize =(12, 8))
 
# set height of bar
IT = [12, 30, 1, 8, 22]
ECE = [28, 6, 16, 5, 10]
CSE = [29, 3, 24, 25, 17]
 
# Set position of bar on X axis
br1 = np.arange(len(IT))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
 
# Make the plot
plt.bar(br1, IT, color ='r', width = barWidth,
        edgecolor ='grey', label ='IT')
plt.bar(br2, ECE, color ='g', width = barWidth,
        edgecolor ='grey', label ='ECE')
plt.bar(br3, CSE, color ='b', width = barWidth,
        edgecolor ='grey', label ='CSE')
 
# Adding Xticks
plt.xlabel('Branch', fontweight ='bold', fontsize = 15)
plt.ylabel('Students passed', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(IT))],
        ['2015', '2016', '2017', '2018', '2019'])
 
plt.legend()
plt.show()

# %%
barWidth = 0.15
fig = plt.subplots(figsize =(20, 10))
br1 = np.arange(len(data['WFS']))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]
br5 = [x + barWidth for x in br4]
# Make the plot
plt.bar(br1, data['WFS'], width = barWidth,
        edgecolor ='grey', label ='WFS')
plt.bar(br2, data['CFS'],  width = barWidth,
        edgecolor ='grey', label ='CFS')
plt.bar(br3, data['RFE'],color='DarkGray', width = barWidth,
        edgecolor ='grey', label ='RFE')
plt.bar(br4, data['Lasso'], color='gray', width = barWidth,
        edgecolor ='grey', label ='RFE')
plt.bar(br5, data['Boruta'],color='LightYellow', width = barWidth,
        edgecolor ='grey', label ='Boruta')

# Adding Xticks
plt.xlabel('Models', fontweight ='bold', fontsize = 18)
plt.ylabel('Computation time', fontweight ='bold', fontsize = 18)
plt.xticks([r + barWidth for r in range(len(data['WFS']))],
        ['ANN', 'LSTM', 'BiLSTM', 'GRU', 'BiGRU','SimpleRNN','MLP'])
plt.title('Computation Time',fontweight ='bold', fontsize = 20)
 
plt.legend()
plt.savefig('Computation Time.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'WFS'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-7a0ed79f9ce3> in <module>()
#       1 barWidth = 0.15
# ...

# %%
plt.rcParams["figure.figsize"] = [18,10]
barWidth = 0.13
# fig = plt.subplots(figsize =(18, 10))
br1 = np.arange(len(data['Accuracy']))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]
# br5 = [x + barWidth for x in br4]
# Make the plot
plt.bar(br1, data['Accuracy'], color ='gray', width = barWidth,
        edgecolor ='grey', label ='WFS')
plt.bar(br2, data['Precision'], color ='gainsboro', width = barWidth,
        edgecolor ='grey', label ='CFS')
plt.bar(br3, data['Recall'], color ='tan', width = barWidth,
        edgecolor ='grey', label ='RFE')
plt.bar(br4, data['F1 Score'], color ='moccasin', width = barWidth,
        edgecolor ='grey', label ='Lasso')
# plt.bar(br5, data['Boruta'], color ='slategrey', width = barWidth,
        # edgecolor ='grey', label ='Boruta')

# Adding Xticks
plt.xlabel('Models', fontsize = 20)
plt.ylabel('Computation time', fontsize = 20)
plt.xticks([r + barWidth for r in range(len(data['Accuracy']))],
        ['Accuracy', 'LSTM', 'BiLSTM', 'GRU', 'BiGRU','SimpleRNN','MLP'],fontsize = 15)
plt.yticks(fontsize = 15)
# plt.title('Computation Time',fontweight ='bold', fontsize = 20)
 
plt.legend(fontsize = 16)
plt.savefig('Computation Time.png')
plt.show()
